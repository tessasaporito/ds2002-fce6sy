# %% [markdown]
# <a href="https://colab.research.google.com/github/tessasaporito/ds2002-fce6sy/blob/main/Mongo_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pymongo certifi
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (2024.8.30)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.6 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 16.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.10.1

# %%
# Install pymongo for MongoDB connection


# Import necessary libraries
from pymongo import MongoClient
import pprint

# Replace with your MongoDB Atlas connection string
connection_string = "mongodb+srv://tessa:uva1819@cluster0.vh17s.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Connect to MongoDB Atlas
client = MongoClient(connection_string)

# Access the sample_mflix database and the movies collection
db = client['sample_mflix']
collection = db['movies']

# %% [markdown]
# exercise 1

# %%
#1
action_movie = collection.find_one({"genres": "Action"})

action_movie
# Out:
# {'_id': ObjectId('573a1390f29313caabcd5293'),
#  'plot': "Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle's secretary has been named as her guardian until she marries, at which time she will officially take ...",
#  'genres': ['Action'],
#  'runtime': 199,
#  'cast': ['Pearl White', 'Crane Wilbur', 'Paul Panzer', 'Edward Josè'],
#  'num_mflix_comments': 0,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzgxODk1Mzk2Ml5BMl5BanBnXkFtZTgwMDg0NzkwMjE@._V1_SY1000_SX677_AL_.jpg',
#  'title': 'The Perils of Pauline',
#  'fullplot': 'Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle\'s secretary has been named as her guardian until she marries, at which time she will officially take possession of her inheritance. Meanwhile, her "guardian" and his confederates constantly come up with schemes to get rid of Pauline so that he can get his hands on the money himself.',
#  'languages': ['English'],
#  'released': datetime.datetime(1914, 3, 23, 0, 0),
#  'directors': ['Louis J. Gasnier', 'Donald MacKenzie'],
#  'writers': ['Charles W. Goddard (screenplay)',
#   'Basil Dickey (screenplay)',
#   'Charles W. Goddard (novel)',
#   'George B. Seitz',
#   'Bertram Millhauser'],
#  'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  'lastupdated': '2015-09-12 00:01:18.647000000',
#  'year': 1914,
#  'imdb': {'rating': 7.6, 'votes': 744, 'id': 4465},
#  'countries': ['USA'],
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 9},
#   'production': 'Pathè Frères',
#   'lastUpdated': datetime.datetime(2015, 9, 11, 17, 46, 19)}}

# %%
#2
movies_after_2000 = collection.find({"year": {"$gt": 2000}}).limit(5)

for movie in movies_after_2000:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1393f29313caabcdcb42'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#  'countries': ['USA'],
#  'directors': ['James Mangold'],
#  'fullplot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#              'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#              'space near the Brooklyn Bridge where there is a gap in time. He '
#              'goes back to the 19th Century and takes pictures of the place. '
#              "Leopold -- a man living in the 1870s -- is puzzled by Stuart's "
#              'tiny camera, follows him back through the gap, and they both '
#              'ended up in the present day. Leopold is clueless about his new '
#              'surroundings. He gets help and insight from Charlie who thinks '
#              'that Leopold is an actor who is always in character. Leopold is '
#              'a highly intelligent man and tries his best to learn and even '
#              'improve the modern conveniences that he encounters.',
#  'genres': ['Comedy', 'Fantasy', 'Romance'],
#  'imdb': {'id': 35423, 'rating': 6.3, 'votes': 59951},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-31 00:19:09.717000000',
#  'metacritic': 44,
#  'num_mflix_comments': 0,
#  'plot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#          'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#          'space near the Brooklyn Bridge where there is a gap in time....',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmNlN2VlOTctYTdhMS00NzUxLTg0ZGMtYWE2ZTJmMThlMTk2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 12, 25, 0, 0),
#  'runtime': 118,
#  'title': 'Kate & Leopold',
#  'tomatoes': {'boxOffice': '$47.1M',
#               'consensus': 'Though Jackman charms, Kate and Leopold is bland '
#                            'and predictable, and the time travel scenario '
#                            'lacks inner logic.',
#               'critic': {'meter': 50, 'numReviews': 126, 'rating': 5.3},
#               'dvd': datetime.datetime(2002, 6, 11, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 53, 25),
#               'production': 'Miramax Films',
#               'rotten': 63,
#               'viewer': {'meter': 62, 'numReviews': 189426, 'rating': 3.0},
#               'website': 'http://www.kateandleopold-themovie.com'},
#  'type': 'movie',
#  'writers': ['Steven Rogers (story)',
#              'James Mangold (screenplay)',
#              'Steven Rogers (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a1398f29313caabceb1fe'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Crispin Glover', 'Vanessa Redgrave', 'John Hurt', 'Margot Kidder'],
#  'countries': ['USA', 'Poland', 'Russia'],
#  'directors': ['Menahem Golan'],
#  'fullplot': "A modern day adaptation of Dostoyevsky's classic novel about a "
#              'young student who is forever haunted by the murder he has '
#              'committed.',
#  'genres': ['Drama'],
#  'imdb': {'id': 96056, 'rating': 6.4, 'votes': 463},
#  'languages': ['English', 'Polish'],
#  'lastupdated': '2015-08-13 00:34:02.303000000',
#  'num_mflix_comments': 0,
#  'plot': "A modern day adaptation of Dostoyevsky's classic novel about a young "
#          'student who is forever haunted by the murder he has committed.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTI3MDQ2MzEyOV5BMl5BanBnXkFtZTcwNzEwODUzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2002, 6, 1, 0, 0),
#  'runtime': 126,
#  'title': 'Crime and Punishment',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 22, 18, 45, 10),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Fyodor Dostoevsky (novel)',
#              'Menahem Golan (adaptation)',
#              'Menahem Golan (screenplay)'],
#  'year': 2002}
# {'_id': ObjectId('573a139af29313caabcf0718'),
#  'awards': {'nominations': 8, 'text': '1 win & 8 nominations.', 'wins': 1},
#  'cast': ['Mariah Carey', 'Max Beesley', 'Da Brat', 'Tia Texada'],
#  'countries': ['USA'],
#  'directors': ['Vondie Curtis-Hall'],
#  'fullplot': 'Billie Frank is a shy, young multiracial girl who is sent away '
#              'by her alcoholic mother at a very early age. At an orphanage, '
#              'she befriends Louise and Roxanne. Flash forward to 1983. Billie '
#              'and her friends are spotted by a record producer, Timothy '
#              'Walker, who wants them to sing backup for his latest pop-music '
#              "discovery. But when super DJ Julian Dice hears Billie's "
#              'incredible voice, he makes a shady deal with Timothy to get her '
#              'out of that dead-end situation. Soon, Billie and Dice are making '
#              'hits inside the studio, and falling in love outside of it. '
#              'Eventually, the pressure of her newfound celebrity puts too '
#              'heavy a strain on Billie, forcing her to decide what it is she '
#              'really wants from Dice, and what she wants for herself.',
#  'genres': ['Drama', 'Music', 'Romance'],
#  'imdb': {'id': 118589, 'rating': 2.1, 'votes': 18840},
#  'languages': ['English'],
#  'lastupdated': '2015-08-21 00:47:31.610000000',
#  'metacritic': 14,
#  'num_mflix_comments': 0,
#  'plot': 'A young singer dates a disc jockey who helps her get into the music '
#          'business, but their relationship become complicated as she ascends '
#          'to super stardom.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMGJkN2IxNTYtZDE1OS00MWJhLWFhNzItNTZkMjM4OGUzMTE2L2ltYWdlXkEyXkFqcGdeQXVyNTg3MTc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 9, 21, 0, 0),
#  'runtime': 104,
#  'title': 'Glitter',
#  'tomatoes': {'boxOffice': '$3.9M',
#               'consensus': 'Glitter is a hodgepodge of movie cliches and bad '
#                            "acting that's sure to generate unintentional "
#                            'laughs. Unfortunately, the movie is not bad enough '
#                            'to be good.',
#               'critic': {'meter': 7, 'numReviews': 87, 'rating': 2.8},
#               'dvd': datetime.datetime(2002, 1, 15, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 18, 37, 3),
#               'production': '20th Century Fox',
#               'rotten': 81,
#               'viewer': {'meter': 45, 'numReviews': 44284, 'rating': 2.1},
#               'website': 'http://216.133.243.94'},
#  'type': 'movie',
#  'writers': ['Cheryl L. West (story)', 'Kate Lanier (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a139af29313caabcf0809'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Marcelo Games', 'Marc Pitman', 'Leslie Orr', 'Maureen Allisse'],
#  'countries': ['USA'],
#  'directors': ['Jim Van Bebber'],
#  'fullplot': 'If you think you know the story of the Manson Family, you are '
#              'dead wrong. On a ranch outside of Los Angeles, the dream of the '
#              '"Love Generation" is transforming into something evil. What was '
#              'once an oasis of free love and acid trips has become ground zero '
#              "for a madman's paranoid visions. An average group of kids, the "
#              '"Family," become engulfed in a delusional world where torment '
#              'and slaughter are considered the path to righteousness.Director '
#              'Jim VanBebber (Deadbeat at Dawn) delivers a dizzying, rapid-fire '
#              'vision of the sex and violence that unifies the misguided group, '
#              'a group hell-bent on executing the brutal vision of its leader, '
#              "Charles Manson. You've seen the story through the eyes of the "
#              'law. Now witness it through the eyes of THE MANSOSN FAMILY.',
#  'genres': ['Crime', 'Drama', 'History'],
#  'imdb': {'id': 118840, 'rating': 5.5, 'votes': 2565},
#  'languages': ['English'],
#  'lastupdated': '2015-09-03 00:41:23.867000000',
#  'metacritic': 56,
#  'num_mflix_comments': 0,
#  'plot': 'If you think you know the story of the Manson Family, you are dead '
#          'wrong. On a ranch outside of Los Angeles, the dream of the "Love '
#          'Generation" is transforming into something evil. What was...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk1NDIzMjY3M15BMl5BanBnXkFtZTcwODE2ODYyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2004, 7, 23, 0, 0),
#  'runtime': 95,
#  'title': 'The Manson Family',
#  'tomatoes': {'critic': {'meter': 68, 'numReviews': 31, 'rating': 6.0},
#               'dvd': datetime.datetime(2005, 4, 26, 0, 0),
#               'fresh': 21,
#               'lastUpdated': datetime.datetime(2015, 7, 20, 18, 38, 35),
#               'production': 'Blue Underground',
#               'rotten': 10,
#               'viewer': {'meter': 48, 'numReviews': 7479, 'rating': 3.0},
#               'website': 'http://www2.themansonfamilymovie.com/'},
#  'type': 'movie',
#  'writers': ['Jim Van Bebber'],
#  'year': 2003}
# {'_id': ObjectId('573a139af29313caabcf0869'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Javier Bardem',
#           'Juan Diego Botto',
#           'Laura Morante',
#           'Elvira Mènguez'],
#  'countries': ['Spain', 'USA'],
#  'directors': ['John Malkovich'],
#  'fullplot': 'The story of Detective Agustin Rejas, a man clinging to the hope '
#              'of an impossible love in an impossible world. Tracking Ezequiel, '
#              'a delusional anarchist who incites the downtrodden masses to '
#              'join in his brutal revolution against the fascist government in '
#              'their unnamed Latin American country, Rejas finds solace in his '
#              'sense of self-respect and the joy that his daughter and wife '
#              "bring him. Then he meets Yolanda--his daughter's soulfully "
#              'beautiful ballet teacher--a woman who sparks his long-forgotten '
#              'passions and represents all that is good and all that is corrupt '
#              'in their troubled country. But she, who appears to be a shelter '
#              "from the storm, may in actuality be the storm's eye. Ultimately, "
#              'as the revolution intensifies and the net closes around hunter '
#              "and hunted alike, the dancer's truth will prove as elusive as "
#              "the revolutionary's cause and the detective's peace.",
#  'genres': ['Drama', 'Thriller', 'Crime'],
#  'imdb': {'id': 118926, 'rating': 7.0, 'votes': 5359},
#  'languages': ['English', 'Quechua', 'Spanish'],
#  'lastupdated': '2015-09-07 01:12:12.077000000',
#  'metacritic': 64,
#  'num_mflix_comments': 0,
#  'plot': 'A police detective in a South American country is dedicated to '
#          'hunting down a revolutionary guerilla leader.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BODE2ODA5OTE1OV5BMl5BanBnXkFtZTYwNzk1MTc2._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2003, 5, 23, 0, 0),
#  'runtime': 132,
#  'title': 'The Dancer Upstairs',
#  'tomatoes': {'boxOffice': '$2.3M',
#               'consensus': 'Javier Bardem is compelling in the lead role as a '
#                            'police detective in search of a violent, '
#                            'mysterious politcal radical, and as a director, '
#                            'John Malkovich proves adept at crafting a '
#                            'suspenseful mood.',
#               'critic': {'meter': 64, 'numReviews': 114, 'rating': 6.4},
#               'dvd': datetime.datetime(2003, 9, 23, 0, 0),
#               'fresh': 73,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 10, 37, 43),
#               'production': 'Fox Searchlight Pictures',
#               'rotten': 41,
#               'viewer': {'meter': 77, 'numReviews': 4793, 'rating': 3.6},
#               'website': 'http://www.foxsearchlight.com/thedancerupstairs/'},
#  'type': 'movie',
#  'writers': ['Nicholas Shakespeare (novel)',
#              'Nicholas Shakespeare (screenplay)'],
#  'year': 2002}

# %%
#3
high_rated_movies = collection.find({"imdb.rating": {"$gt": 8.5}}).limit(5)
high_rated_movies

for movie in high_rated_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1391f29313caabcd9600'),
#  'awards': {'nominations': 0, 'text': '3 wins.', 'wins': 3},
#  'cast': ['Virginia Cherrill',
#           'Florence Lee',
#           'Harry Myers',
#           'Al Ernest Garcia'],
#  'countries': ['USA'],
#  'directors': ['Charles Chaplin'],
#  'fullplot': 'A tramp falls in love with a beautiful blind girl. Her family is '
#              "in financial trouble. The tramp's on-and-off friendship with a "
#              "wealthy man allows him to be the girl's benefactor and suitor.",
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 21749, 'rating': 8.6, 'votes': 93912},
#  'languages': ['English'],
#  'lastupdated': '2015-09-06 00:10:05.493000000',
#  'num_mflix_comments': 0,
#  'plot': 'With the aid of a wealthy erratic tippler, a dewy-eyed tramp who has '
#          'fallen in love with a sightless flower girl accumulates money to be '
#          'able to help her medically.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BY2I4MmM1N2EtM2YzOS00OWUzLTkzYzctNDc5NDg2N2IyODJmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1931, 3, 7, 0, 0),
#  'runtime': 87,
#  'title': 'City Lights',
#  'tomatoes': {'critic': {'meter': 98, 'numReviews': 42, 'rating': 9.0},
#               'dvd': datetime.datetime(2000, 2, 8, 0, 0),
#               'fresh': 41,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 11, 11),
#               'production': 'Twentieth Century Fox Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 96, 'numReviews': 26133, 'rating': 4.4}},
#  'type': 'movie',
#  'writers': ['Charles Chaplin'],
#  'year': 1931}
# {'_id': ObjectId('573a1392f29313caabcdae3d'),
#  'awards': {'nominations': 1, 'text': '3 wins & 1 nomination.', 'wins': 3},
#  'cast': ['Charles Chaplin',
#           'Paulette Goddard',
#           'Henry Bergman',
#           'Tiny Sandford'],
#  'countries': ['USA'],
#  'directors': ['Charles Chaplin'],
#  'fullplot': "Chaplins last 'silent' film, filled with sound effects, was made "
#              'when everyone else was making talkies. Charlie turns against '
#              'modern society, the machine age, (The use of sound in films ?) '
#              'and progress. Firstly we see him frantically trying to keep up '
#              'with a production line, tightening bolts. He is selected for an '
#              'experiment with an automatic feeding machine, but various '
#              'mishaps leads his boss to believe he has gone mad, and Charlie '
#              'is sent to a mental hospital... When he gets out, he is mistaken '
#              'for a communist while waving a red flag, sent to jail, foils a '
#              'jailbreak, and is let out again. We follow Charlie through many '
#              'more escapades before the film is out.',
#  'genres': ['Comedy', 'Drama'],
#  'imdb': {'id': 27977, 'rating': 8.6, 'votes': 123603},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:06:38.867000000',
#  'metacritic': 96,
#  'num_mflix_comments': 1,
#  'plot': 'The Tramp struggles to live in modern industrial society with the '
#          'help of a young homeless woman.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjJiZjMzYzktNjU0NS00OTkxLWEwYzItYzdhYWJjN2QzMTRlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'G',
#  'released': datetime.datetime(1936, 2, 25, 0, 0),
#  'runtime': 87,
#  'title': 'Modern Times',
#  'tomatoes': {'consensus': 'A slapstick skewering of industrialized America, '
#                            'Modern Times is as politically incisive as it is '
#                            'laugh-out-loud hilarious.',
#               'critic': {'meter': 100, 'numReviews': 53, 'rating': 9.0},
#               'dvd': datetime.datetime(2010, 8, 23, 0, 0),
#               'fresh': 53,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 11, 14),
#               'production': 'United Artists',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 38942, 'rating': 4.3},
#               'website': 'http://www.kino.com/moderntimes'},
#  'type': 'movie',
#  'writers': ['Charles Chaplin'],
#  'year': 1936}
# {'_id': ObjectId('573a1393f29313caabcdc810'),
#  'awards': {'nominations': 6,
#             'text': 'Won 3 Oscars. Another 6 wins & 6 nominations.',
#             'wins': 9},
#  'cast': ['Humphrey Bogart', 'Ingrid Bergman', 'Paul Henreid', 'Claude Rains'],
#  'countries': ['USA'],
#  'directors': ['Michael Curtiz'],
#  'fullplot': 'In World War II Casablanca, Rick Blaine, exiled American and '
#              'former freedom fighter, runs the most popular nightspot in town. '
#              'The cynical lone wolf Blaine comes into the possession of two '
#              'valuable letters of transit. When Nazi Major Strasser arrives in '
#              'Casablanca, the sycophantic police Captain Renault does what he '
#              'can to please him, including detaining a Czechoslovak '
#              "underground leader Victor Laszlo. Much to Rick's surprise, "
#              "Lazslo arrives with Ilsa, Rick's one time love. Rick is very "
#              'bitter towards Ilsa, who ran out on him in Paris, but when he '
#              'learns she had good reason to, they plan to run off together '
#              'again using the letters of transit. Well, that was their '
#              'original plan....',
#  'genres': ['Drama', 'Romance', 'War'],
#  'imdb': {'id': 34583, 'rating': 8.6, 'votes': 354005},
#  'languages': ['English', 'French', 'German', 'Italian'],
#  'lastupdated': '2015-09-04 00:22:54.600000000',
#  'num_mflix_comments': 0,
#  'plot': 'Set in Casablanca, Morocco during the early days of World War II: An '
#          'American expatriate meets a former lover, with unforeseen '
#          'complications.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BY2IzZGY2YmEtYzljNS00NTM5LTgwMzUtMzM1NjQ4NGI0OTk0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1943, 1, 23, 0, 0),
#  'runtime': 102,
#  'title': 'Casablanca',
#  'tomatoes': {'consensus': "An undisputed masterpiece and perhaps Hollywood's "
#                            'quintessential statement on love and romance, '
#                            'Casablanca has only improved with age, boasting '
#                            'career-defining performances from Humphrey Bogart '
#                            'and Ingrid Bergman.',
#               'critic': {'meter': 97, 'numReviews': 72, 'rating': 9.3},
#               'dvd': datetime.datetime(2000, 2, 15, 0, 0),
#               'fresh': 70,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 2, 29),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 2,
#               'viewer': {'meter': 95, 'numReviews': 354142, 'rating': 4.1},
#               'website': 'http://www.FathomEvents.com'},
#  'type': 'movie',
#  'writers': ['Julius J. Epstein (screenplay)',
#              'Philip G. Epstein (screenplay)',
#              'Howard Koch (screenplay)',
#              'Murray Burnett (play)',
#              'Joan Alison (play)'],
#  'year': 1942}
# {'_id': ObjectId('573a1393f29313caabcdd7d8'),
#  'awards': {'nominations': 0,
#             'text': 'Nominated for 5 Oscars. Another 7 wins.',
#             'wins': 12},
#  'cast': ['James Stewart', 'Donna Reed', 'Lionel Barrymore', 'Thomas Mitchell'],
#  'countries': ['USA'],
#  'directors': ['Frank Capra'],
#  'fullplot': 'George Bailey has spent his entire life giving of himself to the '
#              'people of Bedford Falls. He has always longed to travel but '
#              'never had the opportunity in order to prevent rich skinflint Mr. '
#              'Potter from taking over the entire town. All that prevents him '
#              "from doing so is George's modest building and loan company, "
#              'which was founded by his generous father. But on Christmas Eve, '
#              "George's Uncle Billy loses the business's $8,000 while intending "
#              'to deposit it in the bank. Potter finds the misplaced money and '
#              'hides it from Billy. When the bank examiner discovers the '
#              'shortage later that night, George realizes that he will be held '
#              'responsible and sent to jail and the company will collapse, '
#              'finally allowing Potter to take over the town. Thinking of his '
#              'wife, their young children, and others he loves will be better '
#              'off with him dead, he contemplates suicide. But the prayers of '
#              'his loved ones result in a gentle angel named Clarence coming to '
#              'earth to help George, with the promise of earning his wings. He '
#              'shows George what things would have been like if he had never '
#              'been born. In a nightmarish vision in which the '
#              'Potter-controlled town is sunk in sex and sin, those George '
#              'loves are either dead, ruined, or miserable. He realizes that he '
#              'has touched many people in a positive way and that his life has '
#              'truly been a wonderful one.',
#  'genres': ['Drama', 'Family', 'Fantasy'],
#  'imdb': {'id': 38650, 'rating': 8.6, 'votes': 245046},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:01:34.393000000',
#  'num_mflix_comments': 1,
#  'plot': 'An angel helps a compassionate but despairingly frustrated '
#          'businessman by showing what life would have been like if he never '
#          'existed.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZjc4NDZhZWMtNGEzYS00ZWU2LThlM2ItNTA0YzQ0OTExMTE2XkEyXkFqcGdeQXVyNjUwMzI2NzU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1947, 1, 7, 0, 0),
#  'runtime': 130,
#  'title': "It's a Wonderful Life",
#  'tomatoes': {'consensus': 'The holiday classic to define all holiday '
#                            "classics, It's a Wonderful Life is one of a "
#                            'handful of films worth an annual viewing.',
#               'critic': {'meter': 94, 'numReviews': 68, 'rating': 8.9},
#               'dvd': datetime.datetime(1995, 9, 19, 0, 0),
#               'fresh': 64,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 10, 55),
#               'production': 'Liberty Films',
#               'rotten': 4,
#               'viewer': {'meter': 95, 'numReviews': 215785, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Frances Goodrich (screenplay)',
#              'Albert Hackett (screenplay)',
#              'Frank Capra (screenplay)',
#              'Jo Swerling (additional scenes)',
#              'Philip Van Doren Stern (story)'],
#  'year': 1946}
# {'_id': ObjectId('573a1394f29313caabcdfa00'),
#  'awards': {'nominations': 7,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 7 nominations.',
#             'wins': 11},
#  'cast': ['James Stewart', 'Grace Kelly', 'Wendell Corey', 'Thelma Ritter'],
#  'countries': ['USA'],
#  'directors': ['Alfred Hitchcock'],
#  'fullplot': 'Professional photographer L.B. "Jeff" Jeffries breaks his leg '
#              'while getting an action shot at an auto race. Confined to his '
#              'New York apartment, he spends his time looking out of the rear '
#              'window observing the neighbors. He begins to suspect that a man '
#              'across the courtyard may have murdered his wife. Jeff enlists '
#              'the help of his high society fashion-consultant girlfriend Lisa '
#              'Freemont and his visiting nurse Stella to investigate.',
#  'genres': ['Mystery', 'Thriller'],
#  'imdb': {'id': 47396, 'rating': 8.6, 'votes': 283273},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:31:57.327000000',
#  'num_mflix_comments': 1,
#  'plot': 'A wheelchair bound photographer spies on his neighbours from his '
#          'apartment window and becomes convinced one of them has committed '
#          'murder.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'runtime': 112,
#  'title': 'Rear Window',
#  'tomatoes': {'consensus': 'Hitchcock exerted full potential of suspense in '
#                            'this masterpiece.',
#               'critic': {'meter': 100, 'numReviews': 63, 'rating': 8.9},
#               'dvd': datetime.datetime(2001, 3, 6, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 7, 38),
#               'production': 'Paramount Pictures',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 147500, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['John Michael Hayes (screenplay)',
#              'Cornell Woolrich (based on the short story by)'],
#  'year': 1954}

# %%
action_adventure_movies = collection.find({"genres": {"$all": ["Action",
"Adventure"]}}).limit(5)

for movie in action_adventure_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1391f29313caabcd820b'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Ronald Colman', 'Neil Hamilton', 'Ralph Forbes', 'Alice Joyce'],
#  'countries': ['USA'],
#  'directors': ['Herbert Brenon'],
#  'fullplot': 'Michael "Beau" Geste leaves England in disgrace and joins the '
#              'infamous French Foreign Legion. He is reunited with his two '
#              'brothers in North Africa, where they face greater danger from '
#              'their own sadistic commander than from the rebellious Arabs.',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 16634, 'rating': 6.9, 'votes': 222},
#  'languages': ['English'],
#  'lastupdated': '2015-08-25 00:40:54.383000000',
#  'num_mflix_comments': 0,
#  'plot': 'Michael "Beau" Geste leaves England in disgrace and joins the '
#          'infamous French Foreign Legion. He is reunited with his two brothers '
#          'in North Africa, where they face greater danger from their...',
#  'released': datetime.datetime(1926, 8, 25, 0, 0),
#  'runtime': 101,
#  'title': 'Beau Geste',
#  'tomatoes': {'dvd': datetime.datetime(2000, 3, 28, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 4, 18, 18, 16, 4),
#               'viewer': {'meter': 38, 'numReviews': 75, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Herbert Brenon (adaptation)',
#              'John Russell (adaptation)',
#              'Paul Schofield',
#              'Percival Christopher Wren (novel)'],
#  'year': 1926}
# {'_id': ObjectId('573a1391f29313caabcd8268'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Billie Dove', 'Tempe Pigott', 'Donald Crisp', 'Sam De Grasse'],
#  'countries': ['USA'],
#  'directors': ['Albert Parker'],
#  'fullplot': 'A nobleman vows to avenge the death of his father at the hands '
#              'of pirates. To this end he infiltrates the pirate band. Acting '
#              'in character he is instrumental in the capture of a ship, but '
#              'things are complicated when he finds that there is a young woman '
#              'on board whom he wishes to protect from the threat of rape.',
#  'genres': ['Adventure', 'Action'],
#  'imdb': {'id': 16654, 'rating': 7.2, 'votes': 1146},
#  'lastupdated': '2015-08-22 01:10:11.970000000',
#  'num_mflix_comments': 1,
#  'plot': 'Seeking revenge, an athletic young man joins the pirate band '
#          "responsible for his father's death.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzU0NDkyMjEzMV5BMl5BanBnXkFtZTgwMTcyMzEyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1926, 3, 8, 0, 0),
#  'runtime': 88,
#  'title': 'The Black Pirate',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 9, 'rating': 8.1},
#               'dvd': datetime.datetime(1999, 10, 12, 0, 0),
#               'fresh': 9,
#               'lastUpdated': datetime.datetime(2015, 7, 22, 19, 23, 50),
#               'rotten': 0,
#               'viewer': {'meter': 70, 'numReviews': 1390, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Douglas Fairbanks (story)', 'Jack Cunningham (adapted by)'],
#  'year': 1926}
# {'_id': ObjectId('573a1392f29313caabcd9cfb'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Johnny Weissmuller',
#           'Neil Hamilton',
#           'C. Aubrey Smith',
#           "Maureen O'Sullivan"],
#  'countries': ['USA'],
#  'directors': ['W.S. Van Dyke'],
#  'fullplot': 'James Parker and Harry Holt are on an expedition in Africa in '
#              'search of the elephant burial grounds that will provide enough '
#              "ivory to make them rich. Parker's beautiful young daughter Jane "
#              'arrives unexpectedly to join them. Harry is obviously attracted '
#              'to Jane and he does his best to help protect her from all the '
#              'dangers that they experience in the jungle. Jane is terrified '
#              'when Tarzan and his ape friends first abduct her, but when she '
#              "returns to her father's expedition she has second thoughts about "
#              'leaving Tarzan. After the expedition is captured by a tribe of '
#              'violent dwarfs, Jane sends Cheetah to bring Tarzan to rescue '
#              'them...',
#  'genres': ['Action', 'Adventure', 'Romance'],
#  'imdb': {'id': 23551, 'rating': 7.2, 'votes': 5182},
#  'languages': ['English'],
#  'lastupdated': '2015-09-01 00:05:45.413000000',
#  'num_mflix_comments': 0,
#  'plot': 'A trader and his daughter set off in search of the fabled graveyard '
#          'of the elephants in deepest Africa, only to encounter a wild man '
#          'raised by apes.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTVlMDAwMDQtMTEzMC00YjhlLWEyYTctNjMzN2M0NGI0MTEwXkEyXkFqcGdeQXVyNDE5MTU2MDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1932, 4, 2, 0, 0),
#  'runtime': 100,
#  'title': 'Tarzan the Ape Man',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 13, 'rating': 7.8},
#               'fresh': 13,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 54, 59),
#               'production': 'MGM Home Entertainment',
#               'rotten': 0,
#               'viewer': {'meter': 69, 'numReviews': 948, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Edgar Rice Burroughs (based upon the characters created by)',
#              'Cyril Hume (adaptation)',
#              'Ivor Novello (dialogue)'],
#  'year': 1932}
# {'_id': ObjectId('573a1392f29313caabcda755'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Clark Gable', 'Jean Harlow', 'Wallace Beery', 'Lewis Stone'],
#  'countries': ['USA'],
#  'directors': ['Tay Garnett'],
#  'fullplot': 'Dynamic Alan Gaskell captains a ship bound from Hong Kong to '
#              'Singapore. Gaskell tries to turn over a new leaf from his '
#              'hard-drinking lifestyle after becoming attached to a refined '
#              'high class English lady, Sybil Barclay. His former girlfriend '
#              'Dolly is extremely jealous of the budding relationship and tries '
#              'hard to get the Captain back. He is apparently unimpressed with '
#              'her loud, obnoxious, and uncivilized manners, even though she is '
#              'extremely beautiful. After a temporary take over of the ship by '
#              'gold-seeking Asian pirates, Captain Gaskell must deal with the '
#              'fact that Dolly and her drinking pal, Jamesey MacArdle, are '
#              'implicated in the crime.',
#  'genres': ['Action', 'Drama', 'Adventure'],
#  'imdb': {'id': 26205, 'rating': 7.0, 'votes': 1518},
#  'languages': ['English'],
#  'lastupdated': '2015-09-11 00:37:56.387000000',
#  'num_mflix_comments': 2,
#  'plot': 'When earthy Dolly Portland is rejected by Captain Gaskell in favor '
#          'of a socialite, she aids Jamesy McCardle, in league with Malay '
#          'pirates, in his plot to seize his ship.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTgxMDg2MzE3MV5BMl5BanBnXkFtZTgwOTM5MjIyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1935, 8, 16, 0, 0),
#  'runtime': 87,
#  'title': 'China Seas',
#  'tomatoes': {'dvd': datetime.datetime(2006, 6, 20, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 7, 23, 18, 45, 51),
#               'production': 'MGM',
#               'viewer': {'meter': 73, 'numReviews': 577, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Jules Furthman (screen play)',
#              'James Kevin McGuinness (screen play)',
#              'Crosbie Garstin (from the book by)'],
#  'year': 1935}
# {'_id': ObjectId('573a1392f29313caabcdac22'),
#  'awards': {'nominations': 4,
#             'text': 'Won 1 Oscar. Another 3 nominations.',
#             'wins': 0},
#  'cast': ['Errol Flynn',
#           'Olivia de Havilland',
#           'Patric Knowles',
#           'Henry Stephenson'],
#  'countries': ['USA'],
#  'directors': ['Michael Curtiz'],
#  'fullplot': 'Major Vickers is an officer at the 27th Lancers in India 1856. '
#              'When the regiment is on maneuver, the barracks are attacked by '
#              'Surat Khan and his soldiers who massacre British women and '
#              'children. This leaves an inextinguishable memory and Vickers '
#              'promises to revenge the dead.',
#  'genres': ['Action', 'Adventure', 'Romance'],
#  'imdb': {'id': 27438, 'rating': 7.1, 'votes': 3187},
#  'languages': ['English'],
#  'lastupdated': '2015-08-20 00:35:09.343000000',
#  'num_mflix_comments': 0,
#  'plot': 'A major countermands orders and attacks to revenge a previous '
#          'massacre of men, women and children.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmUzYjNjZDQtMjNmZS00OGZmLTg2NzgtMjkyYTZkMmFlYTczXkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1936, 10, 20, 0, 0),
#  'runtime': 115,
#  'title': 'The Charge of the Light Brigade',
#  'tomatoes': {'critic': {'meter': 83, 'numReviews': 6, 'rating': 6.8},
#               'dvd': datetime.datetime(2007, 3, 27, 0, 0),
#               'fresh': 5,
#               'lastUpdated': datetime.datetime(2015, 8, 23, 16, 21, 43),
#               'production': 'WARNER BROTHERS PICTURES',
#               'rotten': 1,
#               'viewer': {'meter': 60, 'numReviews': 730, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Alfred Lord Tennyson (poem)',
#              'Michael Jacoby (original story)',
#              'Michael Jacoby (screen play)',
#              'Rowland Leigh (screen play)'],
#  'year': 1936}

# %% [markdown]
# exercise 2

# %%
#1
sorted_comedy_movies = collection.find({"genres": "Comedy"}).sort("imdb.rating", -
1).limit(5)

for movie in sorted_comedy_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13faf29313caabdeca97'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Vasiliy Butkevich',
#           'Pavel Chinaryov',
#           'Fyodor Lavrov',
#           'Elena Nesterova'],
#  'countries': ['Russia'],
#  'directors': ['Mikhail Mestetskiy'],
#  'genres': ['Comedy', 'Drama'],
#  'imdb': {'id': 4767340, 'rating': '', 'votes': ''},
#  'languages': ['Russian'],
#  'lastupdated': '2015-06-18 17:54:37.890000000',
#  'num_mflix_comments': 0,
#  'released': datetime.datetime(2015, 6, 10, 0, 0),
#  'runtime': 97,
#  'title': 'Tryapichnyy soyuz',
#  'type': 'movie',
#  'writers': ['Mikhail Mestetskiy'],
#  'year': 2015}
# {'_id': ObjectId('573a13faf29313caabdeca48'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Aleksandr Pal',
#           'Aleksandr Ilin',
#           'Kristina Kazinskaya',
#           'Nodar Dzhanelidze'],
#  'countries': ['Russia'],
#  'directors': ['Anton Chizhikov', 'Ilya Chizhikov'],
#  'genres': ['Comedy', 'Mystery', 'Thriller'],
#  'imdb': {'id': 4765708, 'rating': '', 'votes': ''},
#  'languages': ['Russian'],
#  'lastupdated': '2015-09-06 00:17:54.620000000',
#  'num_mflix_comments': 1,
#  'released': datetime.datetime(2015, 9, 3, 0, 0),
#  'runtime': 84,
#  'title': 'Paren s nashego kladbishcha',
#  'type': 'movie',
#  'writers': ['Vladimir Seryshev'],
#  'year': 2015}
# {'_id': ObjectId('573a13eef29313caabdd5e69'),
#  'awards': {'nominations': 1, 'text': '2 wins & 1 nomination.', 'wins': 2},
#  'cast': ['Aleksandr Bashirov',
#           'Inna Churikova',
#           'Darya Ekamasova',
#           'Alisa Khazanova'],
#  'countries': ['Russia'],
#  'directors': ['Vasiliy Sigarev'],
#  'genres': ['Comedy'],
#  'imdb': {'id': 3579808, 'rating': '', 'votes': ''},
#  'languages': ['Russian'],
#  'lastupdated': '2015-08-13 00:27:34.003000000',
#  'num_mflix_comments': 0,
#  'released': datetime.datetime(2015, 6, 10, 0, 0),
#  'title': 'Strana Oz',
#  'type': 'movie',
#  'writers': ['Andrey Ilenkov', 'Vasiliy Sigarev'],
#  'year': 2015}
# {'_id': ObjectId('573a13e7f29313caabdc79d0'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Timothy Spall', 'Jacek Koman', 'Jacinta Stapleton', 'Lily Sullivan'],
#  'countries': ['Australia'],
#  'directors': ['Ben Chessell'],
#  'genres': ['Comedy'],
#  'imdb': {'id': 3130302, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-15 00:19:04.600000000',
#  'num_mflix_comments': 1,
#  'released': datetime.datetime(2015, 8, 15, 0, 0),
#  'runtime': 90,
#  'title': 'Sucker',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 27, 18, 11, 33),
#               'viewer': {'numReviews': 0, 'rating': 0.0},
#               'website': 'http://daredevilsmovie.com/'},
#  'type': 'movie',
#  'writers': ['Ben Chessell', 'Lawrence Leung'],
#  'year': 2015}
# {'_id': ObjectId('573a13e6f29313caabdc5478'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Brett Goldstein', 'Catherine Tate', 'Natalia Tena', 'Laura Haddock'],
#  'countries': ['UK'],
#  'directors': ['Jon Drever'],
#  'fullplot': 'Faster than a Speeding Bullet, Crap with Girls: After a freak '
#              'meteor storm turns postman Bob into a superhero, he must face '
#              'his greatest challenge: going on his first date in six years. '
#              'Featuring stellar support from top tier comedic talent, Bob must '
#              'balance international politics, saving the world and getting the '
#              'girl.',
#  'genres': ['Action', 'Comedy', 'Romance'],
#  'imdb': {'id': 3055402, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-25 00:19:50.620000000',
#  'num_mflix_comments': 1,
#  'plot': 'Robert Kenner is a lonely man looking for love. Today, if he can '
#          'actually get his boss to give him some time off, he is going on his '
#          "first date for 6 years. Oh, and he is also the world's only "
#          'SuperHero.',
#  'released': datetime.datetime(2015, 10, 16, 0, 0),
#  'runtime': 85,
#  'title': 'SuperBob',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 2, 18, 14, 13),
#               'viewer': {'numReviews': 4, 'rating': 4.7}},
#  'type': 'movie',
#  'writers': ['William Bridges', 'Jon Drever (story)', 'Brett Goldstein'],
#  'year': 2015}

# %%
#2
sorted_drama_movies = collection.find({"genres": "Drama"}).sort("year", 1).limit(5)

for movie in sorted_drama_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd446f'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Frank Powell',
#           'Grace Henderson',
#           'James Kirkwood',
#           'Linda Arvidson'],
#  'countries': ['USA'],
#  'directors': ['D.W. Griffith'],
#  'fullplot': 'A greedy tycoon decides, on a whim, to corner the world market '
#              "in wheat. This doubles the price of bread, forcing the grain's "
#              'producers into charity lines and further into poverty. The film '
#              'continues to contrast the ironic differences between the lives '
#              'of those who work to grow the wheat and the life of the man who '
#              'dabbles in its sale for profit.',
#  'genres': ['Short', 'Drama'],
#  'imdb': {'id': 832, 'rating': 6.6, 'votes': 1375},
#  'languages': ['English'],
#  'lastupdated': '2015-08-13 00:46:30.660000000',
#  'num_mflix_comments': 1,
#  'plot': 'A greedy tycoon decides, on a whim, to corner the world market in '
#          "wheat. This doubles the price of bread, forcing the grain's "
#          'producers into charity lines and further into poverty. The film...',
#  'rated': 'G',
#  'released': datetime.datetime(1909, 12, 13, 0, 0),
#  'runtime': 14,
#  'title': 'A Corner in Wheat',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 5, 11, 18, 36, 53),
#               'viewer': {'meter': 73, 'numReviews': 109, 'rating': 3.6}},
#  'type': 'movie',
#  'year': 1909}
# {'_id': ObjectId('573a1390f29313caabcd4eaf'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jane Gail', 'Ethel Grandin', 'William H. Turner', 'Matt Moore'],
#  'countries': ['USA'],
#  'directors': ['George Loane Tucker'],
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 3471, 'rating': 6.0, 'votes': 371},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 02:07:14.247000000',
#  'num_mflix_comments': 1,
#  'plot': 'A woman, with the aid of her police officer sweetheart, endeavors to '
#          'uncover the prostitution ring that has kidnapped her sister, and the '
#          'philanthropist who secretly runs it.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYzk0YWQzMGYtYTM5MC00NjM2LWE5YzYtMjgyNDVhZDg1N2YzXkEyXkFqcGdeQXVyMzE0MjY5ODA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-PG',
#  'released': datetime.datetime(1913, 11, 24, 0, 0),
#  'runtime': 88,
#  'title': 'Traffic in Souls',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 10, 18, 33, 55),
#               'viewer': {'meter': 57, 'numReviews': 85, 'rating': 3.0}},
#  'type': 'movie',
#  'year': 1913}
# {'_id': ObjectId('573a1390f29313caabcd516c'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Stanley Hunt',
#           'Sarah Constance Smith Hunt',
#           'Mrs. George Walkus',
#           "Paddy 'Malid"],
#  'countries': ['USA'],
#  'directors': ['Edward S. Curtis'],
#  'genres': ['Drama', 'History'],
#  'imdb': {'id': 4150, 'rating': 5.8, 'votes': 223},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 12:11:37.770000000',
#  'num_mflix_comments': 1,
#  'plot': 'Original advertising for the film describes it as a drama of '
#          'primitive life on the shores of the North Pacific...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE3MjAyNzM5NV5BMl5BanBnXkFtZTgwMjA5OTg5NjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1914, 12, 7, 0, 0),
#  'runtime': 65,
#  'title': 'In the Land of the Head Hunters',
#  'tomatoes': {'dvd': datetime.datetime(2000, 8, 15, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 18, 19, 21, 12),
#               'production': 'World Film Corporation',
#               'viewer': {'meter': 18, 'numReviews': 64, 'rating': 2.7},
#               'website': 'http://www.milestonefilms.com/'},
#  'type': 'movie',
#  'writers': ['Edward S. Curtis (story)'],
#  'year': 1914}
# {'_id': ObjectId('573a1390f29313caabcd56df'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['George Beban', 'Clara Williams', 'J. Frank Burke', 'Leo Willis'],
#  'countries': ['USA'],
#  'directors': ['Reginald Barker'],
#  'fullplot': 'An immigrant leaves his sweetheart in Italy to find a better '
#              'life across the sea in the grimy slums of New York. They are '
#              'eventually reunited and marry. But life in New York is hard and '
#              'tragedy tarnishes their dream of a better life in the new world.',
#  'genres': ['Drama'],
#  'imdb': {'id': 5557, 'rating': 6.4, 'votes': 175},
#  'languages': ['English'],
#  'lastupdated': '2015-07-27 00:07:43.230000000',
#  'num_mflix_comments': 0,
#  'plot': 'An immigrant leaves his sweetheart in Italy to find a better life '
#          'across the sea in the grimy slums of New York. They are eventually '
#          'reunited and marry. But life in New York is hard and ...',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1915, 1, 1, 0, 0),
#  'runtime': 78,
#  'title': 'The Italian',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 7, 24, 19, 30, 2),
#               'viewer': {'meter': 60, 'numReviews': 204, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Thomas H. Ince (story)', 'C. Gardner Sullivan (story)'],
#  'year': 1915}
# {'_id': ObjectId('573a1390f29313caabcd587d'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['John McCann', 'James A. Marcus', 'Maggie Weston', 'Harry McCoy'],
#  'countries': ['USA'],
#  'directors': ['Raoul Walsh'],
#  'fullplot': 'At 10 years old, Owens becomes a ragged orphan when his sainted '
#              'mother dies. The Conways, who are next door neighbors, take Owen '
#              'in, but the constant drinking by Jim soon puts Owen on the '
#              'street. By 17, Owen learns that might is right. By 25, Owen is '
#              'the leader of his own gang who spend most of their time gambling '
#              'and drinking. But Marie comes into the gangster area of town and '
#              'everything changes for Owen as he falls for Marie. But he cannot '
#              'tell her so, so he comes to her settlement to find education and '
#              'inspiration. But soon, his old way of life will rise to confront '
#              'him again.',
#  'genres': ['Biography', 'Crime', 'Drama'],
#  'imdb': {'id': 5960, 'rating': 6.8, 'votes': 626},
#  'languages': ['English'],
#  'lastupdated': '2015-08-14 01:28:18.957000000',
#  'num_mflix_comments': 1,
#  'plot': 'At 10 years old, Owens becomes a ragged orphan when his sainted '
#          'mother dies. The Conways, who are next door neighbors, take Owen in, '
#          'but the constant drinking by Jim soon puts Owen on the ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNDkxZGU4NmMtODJlNy00YzA2LTg4ZGMtNGFlNzAyNzcxOTM1XkEyXkFqcGdeQXVyOTM3MjcyMjI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1915, 9, 13, 0, 0),
#  'runtime': 72,
#  'title': 'Regeneration',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 5, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 11, 27, 0, 0),
#               'fresh': 5,
#               'lastUpdated': datetime.datetime(2015, 9, 17, 17, 22, 42),
#               'production': 'Fox Film Corporation',
#               'rotten': 0,
#               'viewer': {'meter': 70, 'numReviews': 395, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Owen Frawley Kildare (book)',
#              'Raoul Walsh (adapted from the book: "My Mamie Rose")',
#              'Carl Harbaugh (adapted from the book: "My Mamie Rose")'],
#  'year': 1915}

# %% [markdown]
# exercise 3

# %%
#1
avg_rating_by_genre = collection.aggregate([
{"$unwind": "$genres"},
{"$group": {"_id": "$genres", "avg_rating": {"$avg": "$imdb.rating"}}},
{"$sort": {"avg_rating": -1}},
{"$limit": 5}
])

for genre in avg_rating_by_genre:
    pprint.pprint(genre)
# Out:
# {'_id': 'Film-Noir', 'avg_rating': 7.397402597402598}
# {'_id': 'Short', 'avg_rating': 7.377574370709382}
# {'_id': 'Documentary', 'avg_rating': 7.365679824561403}
# {'_id': 'News', 'avg_rating': 7.252272727272728}
# {'_id': 'History', 'avg_rating': 7.1696100917431185}

# %%
#2
top_directors = collection.aggregate([
{"$group": {"_id": "$directors", "avg_rating": {"$avg": "$imdb.rating"}}},
{"$sort": {"avg_rating": -1}},
{"$limit": 5}
])

for director in top_directors:
    pprint.pprint(director)
# Out:
# {'_id': ['Sara Hirsh Bordo'], 'avg_rating': 9.4}
# {'_id': ['Kevin Derek'], 'avg_rating': 9.3}
# {'_id': ['Michael Benson'], 'avg_rating': 9.0}
# {'_id': ['Slobodan Sijan'], 'avg_rating': 8.95}
# {'_id': ['Jeethu Joseph'], 'avg_rating': 8.9}

# %%
#3
movies_per_year = collection.aggregate([
{"$group": {"_id": "$year", "total_movies": {"$sum": 1}}},
{"$sort": {"_id": 1}}
])

for year in movies_per_year:
    pprint.pprint(year)
# Out:
# {'_id': 1896, 'total_movies': 2}
# {'_id': 1903, 'total_movies': 1}
# {'_id': 1909, 'total_movies': 1}
# {'_id': 1911, 'total_movies': 2}
# {'_id': 1913, 'total_movies': 1}
# {'_id': 1914, 'total_movies': 3}
# {'_id': 1915, 'total_movies': 2}
# {'_id': 1916, 'total_movies': 2}
# {'_id': 1917, 'total_movies': 2}
# {'_id': 1918, 'total_movies': 1}
# {'_id': 1919, 'total_movies': 1}
# {'_id': 1920, 'total_movies': 4}
# {'_id': 1921, 'total_movies': 5}
# {'_id': 1922, 'total_movies': 3}
# {'_id': 1923, 'total_movies': 2}
# {'_id': 1924, 'total_movies': 6}
# {'_id': 1925, 'total_movies': 3}
# {'_id': 1926, 'total_movies': 6}
# {'_id': 1927, 'total_movies': 4}
# {'_id': 1928, 'total_movies': 8}
# {'_id': 1929, 'total_movies': 7}
# {'_id': 1930, 'total_movies': 10}
# {'_id': 1931, 'total_movies': 20}
# {'_id': 1932, 'total_movies': 18}
# {'_id': 1933, 'total_movies': 20}
# {'_id': 1934, 'total_movies': 23}
# {'_id': 1935, 'total_movies': 31}
# {'_id': 1936, 'total_movies': 30}
# {'_id': 1937, 'total_movies': 31}
# {'_id': 1938, 'total_movies': 38}
# {'_id': 1939, 'total_movies': 20}
# {'_id': 1940, 'total_movies': 24}
# {'_id': 1941, 'total_movies': 24}
# {'_id': 1942, 'total_movies': 30}
# {'_id': 1943, 'total_movies': 32}
# {'_id': 1944, 'total_movies': 23}
# {'_id': 1945, 'total_movies': 29}
# {'_id': 1946, 'total_movies': 34}
# {'_id': 1947, 'total_movies': 29}
# {'_id': 1948, 'total_movies': 56}
# {'_id': 1949, 'total_movies': 52}
# {'_id': 1950, 'total_movies': 55}
# {'_id': 1951, 'total_movies': 54}
# {'_id': 1952, 'total_movies': 45}
# {'_id': 1953, 'total_movies': 65}
# {'_id': 1954, 'total_movies': 47}
# {'_id': 1955, 'total_movies': 67}
# {'_id': 1956, 'total_movies': 67}
# {'_id': 1957, 'total_movies': 71}
# {'_id': 1958, 'total_movies': 75}
# {'_id': 1959, 'total_movies': 71}
# {'_id': 1960, 'total_movies': 73}
# {'_id': 1961, 'total_movies': 68}
# {'_id': 1962, 'total_movies': 70}
# {'_id': 1963, 'total_movies': 69}
# {'_id': 1964, 'total_movies': 86}
# {'_id': 1965, 'total_movies': 77}
# {'_id': 1966, 'total_movies': 87}
# {'_id': 1967, 'total_movies': 81}
# {'_id': 1968, 'total_movies': 89}
# {'_id': 1969, 'total_movies': 107}
# {'_id': 1970, 'total_movies': 120}
# {'_id': 1971, 'total_movies': 106}
# {'_id': 1972, 'total_movies': 121}
# {'_id': 1973, 'total_movies': 112}
# {'_id': 1974, 'total_movies': 103}
# {'_id': 1975, 'total_movies': 107}
# {'_id': 1976, 'total_movies': 116}
# {'_id': 1977, 'total_movies': 123}
# {'_id': 1978, 'total_movies': 128}
# {'_id': 1979, 'total_movies': 131}
# {'_id': 1980, 'total_movies': 167}
# {'_id': 1981, 'total_movies': 168}
# {'_id': 1982, 'total_movies': 177}
# {'_id': 1983, 'total_movies': 161}
# {'_id': 1984, 'total_movies': 199}
# {'_id': 1985, 'total_movies': 189}
# {'_id': 1986, 'total_movies': 190}
# {'_id': 1987, 'total_movies': 222}
# {'_id': 1988, 'total_movies': 251}
# {'_id': 1989, 'total_movies': 232}
# {'_id': 1990, 'total_movies': 225}
# {'_id': 1991, 'total_movies': 238}
# {'_id': 1992, 'total_movies': 270}
# {'_id': 1993, 'total_movies': 274}
# {'_id': 1994, 'total_movies': 305}
# {'_id': 1995, 'total_movies': 372}
# {'_id': 1996, 'total_movies': 407}
# {'_id': 1997, 'total_movies': 439}
# {'_id': 1998, 'total_movies': 513}
# {'_id': 1999, 'total_movies': 515}
# {'_id': 2000, 'total_movies': 581}
# {'_id': 2001, 'total_movies': 612}
# {'_id': 2002, 'total_movies': 622}
# {'_id': 2003, 'total_movies': 603}
# {'_id': 2004, 'total_movies': 678}
# {'_id': 2005, 'total_movies': 713}
# {'_id': 2006, 'total_movies': 774}
# {'_id': 2007, 'total_movies': 810}
# {'_id': 2008, 'total_movies': 886}
# {'_id': 2009, 'total_movies': 917}
# {'_id': 2010, 'total_movies': 866}
# {'_id': 2011, 'total_movies': 893}
# {'_id': 2012, 'total_movies': 955}
# {'_id': 2013, 'total_movies': 1105}
# {'_id': 2014, 'total_movies': 1073}
# {'_id': 2015, 'total_movies': 480}
# {'_id': 2016, 'total_movies': 1}
# {'_id': '1981è', 'total_movies': 1}
# {'_id': '1986è', 'total_movies': 1}
# {'_id': '1987è', 'total_movies': 1}
# {'_id': '1988è', 'total_movies': 1}
# {'_id': '1994è1998', 'total_movies': 1}
# {'_id': '1995è', 'total_movies': 1}
# {'_id': '1996è', 'total_movies': 1}
# {'_id': '1997è', 'total_movies': 2}
# {'_id': '1999è', 'total_movies': 1}
# {'_id': '2000è', 'total_movies': 1}
# {'_id': '2002è', 'total_movies': 1}
# {'_id': '2003è', 'total_movies': 1}
# {'_id': '2005è', 'total_movies': 2}
# {'_id': '2006è', 'total_movies': 1}
# {'_id': '2006è2007', 'total_movies': 1}
# {'_id': '2006è2012', 'total_movies': 2}
# {'_id': '2007è', 'total_movies': 3}
# {'_id': '2009è', 'total_movies': 2}
# {'_id': '2010è', 'total_movies': 4}
# {'_id': '2011è', 'total_movies': 2}
# {'_id': '2012è', 'total_movies': 3}
# {'_id': '2014è', 'total_movies': 2}

# %% [markdown]
# exercise 4

# %%
#1
collection.update_one({"title": "The Godfather"}, {"$set": {"imdb.rating": 9.5}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000d6e'), 'opTime': {'ts': Timestamp(1727984600, 13), 't': 3438}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1727984600, 14), 'signature': {'hash': b'\xc0\x03\xdaAL\x00J\xa6y\xac\x13(H\x81;\x92z9Wt', 'keyId': 7361148627617579060}}, 'operationTime': Timestamp(1727984600, 13), 'updatedExisting': True}, acknowledged=True)

# %%
#2
collection.update_many({"genres": "Horror", "imdb.rating": {"$exists": False}}, {"$set":
{"imdb.rating": 6.0}})
# Out:
# UpdateResult({'n': 0, 'electionId': ObjectId('7fffffff0000000000000d6e'), 'opTime': {'ts': Timestamp(1727984626, 25), 't': 3438}, 'nModified': 0, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1727984626, 25), 'signature': {'hash': b'm\x16\xe9(\xd8j\xd8t\xbag\x8b\x13\x9e\xbbF\x98\xab\xa1\xc9\xd9', 'keyId': 7361148627617579060}}, 'operationTime': Timestamp(1727984626, 25), 'updatedExisting': False}, acknowledged=True)

# %%
#3
collection.delete_many({"year": {"$lt": 1950}})
# Out:
# DeleteResult({'n': 640, 'electionId': ObjectId('7fffffff0000000000000d6e'), 'opTime': {'ts': Timestamp(1727984655, 477), 't': 3438}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1727984655, 484), 'signature': {'hash': b'EV\x04\xe5z\xff\xf3\\\x90_8UKZ\x9d\xf8\xc3\x86A,', 'keyId': 7361148627617579060}}, 'operationTime': Timestamp(1727984655, 477)}, acknowledged=True)

# %% [markdown]
# exercise 5

# %%
#1
collection.create_index([("title", "text")])

love_movies = collection.find({"$text": {"$search": "love"}})

for movie in love_movies:
    print(movie)
# Out:
# {'_id': ObjectId('573a13a6f29313caabd19168'), 'plot': 'A young woman who is in love with a married doctor becomes dangerous when her attempts to persuade him to leave his wife are unsuccessful. However, when things are seen from his point of view, the real situation becomes clear.', 'genres': ['Romance', 'Thriller'], 'runtime': 92, 'metacritic': 63, 'rated': 'PG-13', 'cast': ['Audrey Tautou', 'Samuel Le Bihan', 'Isabelle Carrè', 'Sophie Guillemin'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMjE0NzcwMjM4Ml5BMl5BanBnXkFtZTcwMjgyMjEyMQ@@._V1_SY1000_SX677_AL_.jpg', 'title': 'He Loves Me... He Loves Me Not', 'fullplot': 'Angelique, a young student, is in love with a married doctor. We see her attempts to make him leave his pregnant wife, but he does not appear for meetings or finally the booked journey to Florence. Then the movie is turned back to the beginning, and the view changes: We are now following the view of the doctor instead of Angeliques. And things look quite different now...', 'languages': ['French'], 'released': datetime.datetime(2002, 3, 27, 0, 0), 'directors': ['Laetitia Colombani'], 'writers': ['Laetitia Colombani', 'Caroline Thivel (collaborating writer)'], 'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'}, 'lastupdated': '2015-09-10 17:15:26.557000000', 'year': 2002, 'imdb': {'rating': 7.3, 'votes': 15360, 'id': 291579}, 'countries': ['France'], 'type': 'movie', 'tomatoes': {'website': 'http://www.helovesmethemovie.com', 'viewer': {'rating': 3.8, 'numReviews': 22933, 'meter': 85}, 'dvd': datetime.datetime(2003, 8, 12, 0, 0), 'critic': {'rating': 6.8, 'numReviews': 71, 'meter': 73}, 'boxOffice': '$0.4M', 'consensus': "This romantic thriller puts Tautou's sweetheart Amelie image to good use.", 'rotten': 19, 'production': 'Samuel Goldwyn Company', 'lastUpdated': datetime.datetime(2015, 7, 23, 18, 42, 57), 'fresh': 52}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a139af29313caabcf1a82'), 'countries': ['Czechoslovakia'], 'genres': ['Drama', 'Romance'], 'runtime': 95, 'cast': ['Roman Klosowski', 'Iva Janzurovè', 'Milan Jelic', 'Milada Jezkovè'], 'title': 'I Love, You Love', 'lastupdated': '2015-03-15 00:52:30.840000000', 'languages': ['Slovak'], 'released': datetime.datetime(1989, 2, 15, 0, 0), 'directors': ['Dusan Hanèk'], 'writers': ['Dusan Dusek', 'Dusan Hanèk'], 'awards': {'wins': 2, 'nominations': 1, 'text': '2 wins & 1 nomination.'}, 'year': 1989, 'imdb': {'rating': 7.2, 'votes': 91, 'id': 123920}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 888, 'meter': 61}, 'dvd': datetime.datetime(2000, 7, 11, 0, 0), 'critic': {'rating': 5.8, 'numReviews': 5, 'meter': 60}, 'lastUpdated': datetime.datetime(2015, 9, 11, 17, 56, 34), 'rotten': 2, 'production': 'Strand', 'fresh': 3}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a13bcf29313caabd56e29'), 'countries': ['UK'], 'genres': ['Documentary', 'Romance'], 'runtime': 50, 'cast': ['Mark Strong'], 'num_mflix_comments': 1, 'title': 'Love Me, Love My Doll', 'lastupdated': '2015-08-06 00:20:05.913000000', 'languages': ['English'], 'released': datetime.datetime(2007, 1, 17, 0, 0), 'directors': ['Nick Holt'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'year': 2007, 'imdb': {'rating': 7.2, 'votes': 170, 'id': 968743}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.8, 'numReviews': 671}, 'lastUpdated': datetime.datetime(2015, 7, 20, 18, 57, 39)}}
# {'_id': ObjectId('573a13a0f29313caabd04510'), 'plot': "David, a recently fired scrapyard worker and Marie, a prostitute, both about 20 years old, meet on New Year's Eve in Berlin and decide to run away together. As David's arm is plastered from...", 'genres': ['Drama', 'Romance'], 'runtime': 137, 'cast': ['Sabine Timoteo', 'Florian Stetter', 'Michael Schech', 'Dierk Prawdzik'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMTg0ODU5MTIxNF5BMl5BanBnXkFtZTcwNjk0NDQyMQ@@._V1_SY1000_SX677_AL_.jpg', 'title': 'Love, Money, Love', 'fullplot': "David, a recently fired scrapyard worker and Marie, a prostitute, both about 20 years old, meet on New Year's Eve in Berlin and decide to run away together. As David's arm is plastered from an accident Marie continues to prostitute herself to finance their restless journey through the Ruhr area. Their love and their will to survive guide them though all problems.", 'languages': ['German'], 'released': datetime.datetime(2002, 11, 21, 0, 0), 'directors': ['Philip Grèning'], 'writers': ['Michael Busch', 'Philip Grèning'], 'awards': {'wins': 6, 'nominations': 5, 'text': '6 wins & 5 nominations.'}, 'lastupdated': '2015-07-28 00:13:00.043000000', 'year': 2000, 'imdb': {'rating': 4.0, 'votes': 469, 'id': 203297}, 'countries': ['Germany', 'Switzerland', 'France'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 2.9, 'numReviews': 2131, 'meter': 48}, 'dvd': datetime.datetime(2000, 1, 11, 0, 0), 'production': 'Full Moon', 'lastUpdated': datetime.datetime(2015, 9, 11, 17, 56, 4)}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a13f1f29313caabddb616'), 'plot': "A sexual melodrama about a boy and a girl and another girl. It's a love story, which celebrates sex in a joyous way.", 'genres': ['Drama', 'Romance'], 'runtime': 134, 'metacritic': 54, 'cast': ['Aomi Muyock', 'Karl Glusman', 'Klara Kristin', 'Juan Saavedra'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNDUwODk5NF5BMl5BanBnXkFtZTgwNzA0MDQ2NTE@._V1_SY1000_SX677_AL_.jpg', 'title': 'Love', 'fullplot': "A sexual melodrama about a boy and a girl and another girl. It's a love story, which celebrates sex in a joyous way.", 'languages': ['English'], 'released': datetime.datetime(2015, 11, 6, 0, 0), 'directors': ['Gaspar Noè'], 'writers': ['Gaspar Noè'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-09-05 00:41:35.807000000', 'year': 2015, 'imdb': {'rating': 6.3, 'votes': 660, 'id': 3774694}, 'countries': ['France', 'Belgium'], 'type': 'movie'}
# {'_id': ObjectId('573a13b3f29313caabd3e311'), 'plot': "Told through a looping, non-linear narrative from each of the characters' points of view, the film reconstructs the stories of a Yugoslav hit man, his former lover and her police officer boyfriend, as their paths cross in New York.", 'genres': ['Drama', 'Thriller'], 'runtime': 90, 'metacritic': 79, 'cast': ['Sergej Trifunovic', 'Geno Lechner', 'Peter Gevisser', 'Didier Flamand'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMTcyNzY0OTk1NV5BMl5BanBnXkFtZTcwMDI2Njc0MQ@@._V1_SY1000_SX677_AL_.jpg', 'title': 'Love', 'fullplot': "A narrator introduces several characters as we watch events unfold from various vantages: Vanya is a Yugoslavian, adrift after his country's breakup. He's a hitman, now in New York. Anna is a physician, European, in New York after volunteer work in Bosnia. Dirk is a policeman, Anna's boyfriend, seemingly on temporary leave. Vanya's on what's to be a simple job, no violence, an exchange in a hotel. He arrives to find a dead body. He takes the case he's to pick up. Has he been set up? A murderer seems to be right behind him. Anna, in the hotel to see a patient, becomes his hostage while Dirk waits for her outside, ignorant of the deaths nearby. Can Dirk find Anna? What else is going on?", 'languages': ['English'], 'released': datetime.datetime(2005, 4, 21, 0, 0), 'directors': ['Vladan Nikolic'], 'writers': ['Vladan Nikolic'], 'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'}, 'lastupdated': '2015-08-02 00:35:52.090000000', 'year': 2005, 'imdb': {'rating': 6.0, 'votes': 253, 'id': 450363}, 'countries': ['USA', 'Serbia and Montenegro'], 'type': 'movie', 'tomatoes': {'website': 'http://www.lovethefilm.com', 'viewer': {'rating': 3.4, 'numReviews': 896, 'meter': 44}, 'dvd': datetime.datetime(2007, 7, 17, 0, 0), 'critic': {'rating': 7.4, 'numReviews': 6, 'meter': 100}, 'lastUpdated': datetime.datetime(2015, 9, 11, 17, 54, 48), 'rotten': 0, 'production': 'Koch Vision', 'fresh': 6}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a1396f29313caabce4781'), 'plot': 'The wife of a political prisoner tends to her mother-in-law and keeps from the old woman the truth about her son, whom she believes is in New York making a film.', 'genres': ['Drama'], 'runtime': 88, 'cast': ['Lili Darvas', 'Mari Tèrècsik', 'Ivèn Darvas', 'Erzsi Orsolya'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BMTk5NDEzNzI1Ml5BMl5BanBnXkFtZTcwMzgyMjEzMQ@@._V1_SY1000_SX677_AL_.jpg', 'title': 'Love', 'fullplot': "Luca regularly visits her bedridden mother-in-law. Luca's husband, Jènos, has been arrested on a trumped up political charge, and Luca does not know if he is still alive. Luca hides this from his mother by making up letters purporting to be from Jènos who is directing a big film in New York. Luca discovers that Jènos is alive, and is dismissed from her teaching job because of her husband. The dying mother anxiously awaits the return of her son from New York.", 'languages': ['Hungarian', 'German'], 'released': datetime.datetime(1973, 3, 22, 0, 0), 'directors': ['Kèroly Makk'], 'writers': ['Pèter Bacsè', 'Tibor Dèry (novel)'], 'awards': {'wins': 6, 'nominations': 1, 'text': '6 wins & 1 nomination.'}, 'lastupdated': '2015-07-30 00:05:30.567000000', 'year': 1971, 'imdb': {'rating': 8.1, 'votes': 1055, 'id': 67814}, 'countries': ['Hungary'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 547, 'meter': 93}, 'lastUpdated': datetime.datetime(2015, 8, 18, 19, 19, 39)}}
# {'_id': ObjectId('573a13def29313caabdb5e3e'), 'plot': "The relationship of a young successful couple expecting a baby is put to the test after the traumatic experience Maria has endured. Her husband Tomek wants to seek revenge but doesn't know who is to blame.", 'genres': ['Drama', 'Romance'], 'runtime': 105, 'cast': ['Marcin Dorocinski', 'Julia Kijowska', 'Adam Woronowicz', 'Agata Kulesza'], 'num_mflix_comments': 0, 'title': 'Loving', 'fullplot': "Maria and Tomek are in their thirties and have been married for ten years now. They live in an anonymous Polish town. Both find professional fulfillment in their jobs - he's a designer, she works in the town hall. They are working together on the decoration of their apartment and are expecting a baby. It seems that nothing is capable of disturbing their peaceful lives. But one day the mayor, who has long been attracted to Maria, rapes her. She decides not to report this to the police. Nor does she tell her husband. From that day forth, their love is put to the test.", 'languages': ['Polish'], 'released': datetime.datetime(2012, 10, 1, 0, 0), 'directors': ['Slawomir Fabicki'], 'writers': ['Slawomir Fabicki', 'Marek Pruchniewski'], 'awards': {'wins': 2, 'nominations': 4, 'text': '2 wins & 4 nominations.'}, 'lastupdated': '2015-09-17 04:51:50.340000000', 'year': 2012, 'imdb': {'rating': 6.9, 'votes': 185, 'id': 2495212}, 'countries': ['Poland'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 7}, 'lastUpdated': datetime.datetime(2015, 5, 1, 19, 4, 53)}}
# {'_id': ObjectId('573a13c7f29313caabd73eb4'), 'plot': 'Follows four friends in their quest to form a punk band. As workers protests sweep across the country, Janek and Staszek, the sons of a navy man, the rebellious Kazik, and the affluent ...', 'genres': ['Comedy', 'Drama', 'Music'], 'runtime': 95, 'cast': ['Mateusz Kosciukiewicz', 'Olga Frycz', 'Jakub Gierszal', 'Andrzej Chyra'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BODgxOGFiY2UtNmE2NS00YTc4LTkyNDAtOTk4MjFhYjk0YTUwL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNTcyNTg3Nzc@._V1_SY1000_SX677_AL_.jpg', 'title': 'All That I Love', 'fullplot': 'Follows four friends in their quest to form a punk band. As workers protests sweep across the country, Janek and Staszek, the sons of a navy man, the rebellious Kazik, and the affluent Diabel gel as a band, but their disparate lives are touched by social turmoil and outside perceptions.', 'languages': ['Polish'], 'released': datetime.datetime(2010, 1, 15, 0, 0), 'directors': ['Jacek Borcuch'], 'writers': ['Jacek Borcuch'], 'awards': {'wins': 5, 'nominations': 8, 'text': '5 wins & 8 nominations.'}, 'lastupdated': '2015-08-31 00:06:02.233000000', 'year': 2009, 'imdb': {'rating': 6.9, 'votes': 1137, 'id': 1442584}, 'countries': ['Poland'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 0}, 'production': 'A3 distribution', 'lastUpdated': datetime.datetime(2015, 1, 17, 14, 51, 19)}}
# {'_id': ObjectId('573a13c1f29313caabd65789'), 'plot': 'A tragic love story set at the turn of the millennium in Milan. The film follows the fall of the haute bourgeoisie due to the forces of passion and unconditional love.', 'genres': ['Drama', 'Romance'], 'runtime': 120, 'metacritic': 79, 'rated': 'R', 'cast': ['Tilda Swinton', 'Flavio Parenti', 'Edoardo Gabbriellini', 'Alba Rohrwacher'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMjAwNjY5OTUxM15BMl5BanBnXkFtZTcwNjE3MTQxMw@@._V1_SY1000_SX677_AL_.jpg', 'title': 'I Am Love', 'fullplot': "Over two decades ago, Emma left Russia to follow Tancredi Recchi, the man who had proposed to her. Now a member of a powerful industrial Milanese family, she is the respected mother of three. But Emma, although not unhappy, feels confusedly unfulfilled. One day Antonio, a talented chef and her son's friend and partner, makes her senses kindle. It does not take long before she embarks on a passionate affair with the sensuous young man.", 'languages': ['Italian', 'Russian', 'English'], 'released': datetime.datetime(2010, 7, 23, 0, 0), 'directors': ['Luca Guadagnino'], 'writers': ['Barbara Alberti (screenplay)', 'Ivan Cotroneo (screenplay)', 'Walter Fasano (screenplay)', 'Luca Guadagnino (screenplay)', 'Luca Guadagnino (story)'], 'awards': {'wins': 17, 'nominations': 29, 'text': 'Nominated for 1 Oscar. Another 16 wins & 29 nominations.'}, 'lastupdated': '2015-08-28 00:09:38.160000000', 'year': 2009, 'imdb': {'rating': 7.0, 'votes': 12642, 'id': 1226236}, 'countries': ['Italy'], 'type': 'movie', 'tomatoes': {'website': 'http://www.iamlovemovie.com/', 'viewer': {'rating': 3.5, 'numReviews': 15802, 'meter': 68}, 'dvd': datetime.datetime(2010, 10, 12, 0, 0), 'critic': {'rating': 7.2, 'numReviews': 123, 'meter': 80}, 'boxOffice': '$5.0M', 'consensus': 'It stumbles into melodrama, but I Am Love backs up its flamboyance with tremendous visual style and a marvelous central performance from Tilda Swinton.', 'rotten': 24, 'production': 'Magnolia Pictures', 'lastUpdated': datetime.datetime(2015, 8, 23, 18, 12, 14), 'fresh': 99}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a13bdf29313caabd5864c'), 'plot': 'Antoine Mèliot is around 40 years old and has everything he needs to be happy: a beautiful wife, two adorable children, friends he can count on, a pretty house in the Yvelines and money. ...', 'genres': ['Drama', 'Romance'], 'runtime': 85, 'cast': ['Albert Dupontel', 'Marie-Josèe Croze', 'Pierre Vaneck', 'Cristiana Rèali'], 'num_mflix_comments': 1, 'title': 'Love Me No More', 'fullplot': 'Antoine Mèliot is around 40 years old and has everything he needs to be happy: a beautiful wife, two adorable children, friends he can count on, a pretty house in the Yvelines and money. But one day he decides to ruin everything in one weekend.', 'languages': ['French'], 'released': datetime.datetime(2008, 4, 30, 0, 0), 'directors': ['Jean Becker'], 'writers': ["Franèois d'èpenoux (novel)", 'Eric Assous (adaptation)', "Franèois d'èpenoux (adaptation)", 'Jean Becker (adaptation)', 'Jèrème Beaujour'], 'awards': {'wins': 0, 'nominations': 5, 'text': '5 nominations.'}, 'lastupdated': '2015-09-02 00:00:28.133000000', 'year': 2008, 'imdb': {'rating': 7.1, 'votes': 2059, 'id': 996930}, 'countries': ['France'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 2766, 'meter': 78}, 'dvd': datetime.datetime(2008, 1, 27, 0, 0), 'production': 'Sèville Pictures', 'lastUpdated': datetime.datetime(2015, 8, 26, 18, 4, 38)}}
# {'_id': ObjectId('573a13bbf29313caabd538de'), 'plot': 'Julian has lived off with the money he lures from his rich female customers. But now he faces usurious debts from a hasty expansion of his business, and he will be killed unless he clears ...', 'genres': ['Romance'], 'runtime': 119, 'cast': ['Ju-hyuk Kim', 'Geun-young Moon', 'Seong-ho Choi', 'Si-yeon Jeong'], 'num_mflix_comments': 0, 'title': 'Love Me Not', 'fullplot': "Julian has lived off with the money he lures from his rich female customers. But now he faces usurious debts from a hasty expansion of his business, and he will be killed unless he clears the debt in one month. The only way to save himself is to pretend to be the long-lost brother of an heiress and kill her to get her huge fortune. Ryoo Min (Moon Geun-Young), the blind heiress, cold-hearted like Julian, slowly opens herself to him, and he, too, falls for her. But Julian has to pay his creditor and what makes it worse for him is that the illness that took Ryoo Min's eyesight relapsed, threatening her life.", 'languages': ['Korean'], 'released': datetime.datetime(2006, 11, 9, 0, 0), 'directors': ['Cheol-ha Lee'], 'writers': ['Cheol-ha Lee', 'Seon-jeong Kim', 'Jae-yeon Kim', 'Tae-Yeon Won (letters)', 'Yukari Tatsui (original story)'], 'awards': {'wins': 0, 'nominations': 3, 'text': '3 nominations.'}, 'lastupdated': '2015-08-17 00:03:21.483000000', 'year': 2006, 'imdb': {'rating': 7.0, 'votes': 402, 'id': 904068}, 'countries': ['South Korea'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 425, 'meter': 81}, 'lastUpdated': datetime.datetime(2015, 9, 12, 19, 40, 30)}}
# {'_id': ObjectId('573a13baf29313caabd51faa'), 'plot': 'In nineteenth-century Russia, a teenage boy in search of love is drawn to two very different women.', 'genres': ['Animation', 'Short', 'Drama'], 'runtime': 26, 'cast': ['Aleksandr Palamishev', 'Aleksandra Zhivova', 'Evgeniya Kryukova', 'Nina Ruslanova'], 'num_mflix_comments': 0, 'title': 'My Love', 'lastupdated': '2015-07-12 00:44:44.030000000', 'languages': ['Russian'], 'released': datetime.datetime(2008, 2, 15, 0, 0), 'directors': ['Aleksandr Petrov'], 'writers': ['Ivan Shmelyov (screenplay)'], 'awards': {'wins': 13, 'nominations': 1, 'text': 'Nominated for 1 Oscar. Another 12 wins & 1 nomination.'}, 'year': 2006, 'imdb': {'rating': 8.0, 'votes': 910, 'id': 874952}, 'countries': ['Russia', 'Japan'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 90, 'meter': 89}, 'lastUpdated': datetime.datetime(2015, 8, 26, 18, 10, 15)}}
# {'_id': ObjectId('573a13b4f29313caabd3fb5c'), 'countries': ['Taiwan', 'China', 'Japan'], 'genres': ['Romance'], 'runtime': 102, 'cast': ['Bo-lin Chen', 'Mavis Fan', 'Yui Ichikawa', 'Misaki Itè'], 'num_mflix_comments': 0, 'title': 'About Love', 'lastupdated': '2015-08-20 01:24:46.593000000', 'languages': ['Japanese', 'Mandarin'], 'released': datetime.datetime(2005, 4, 15, 0, 0), 'directors': ['Ten Shimoyama', 'Chih-yen Yee', 'Yibai Zhang'], 'writers': ['Haruko Nagatsu', 'Wei Shen', 'Takuji Ushiyama', 'Chih-yen Yee'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'year': 2005, 'imdb': {'rating': 7.0, 'votes': 712, 'id': 456821}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 386, 'meter': 80}, 'lastUpdated': datetime.datetime(2015, 7, 27, 18, 57, 16)}}
# {'_id': ObjectId('573a13b3f29313caabd3aeb6'), 'plot': 'The fifty years old Jean-Claude has a boring life, working in a notary office of his own and as court official evicting tenants or seizing properties, or spending the Sundays afternoons in ...', 'genres': ['Drama', 'Romance'], 'runtime': 93, 'cast': ['Patrick Chesnais', 'Anne Consigny', 'Georges Wilson', 'Lionel Abelanski'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMmQ5ZmJkYmQtMDk3Yy00ZWM3LWI4NTctOTI2Y2JjOGQzMjZlXkEyXkFqcGdeQXVyNDkzMTE3Ng@@._V1_SY1000_SX677_AL_.jpg', 'title': 'Not Here to Be Loved', 'fullplot': 'The fifty years old Jean-Claude has a boring life, working in a notary office of his own and as court official evicting tenants or seizing properties, or spending the Sundays afternoons in the retirement home with his sour, rude and bitter father. When he has a minor heart problem, his doctor advises him to exercise, and Jean-Claude begins to have tango lessons in a studio in front of his office. He meets the charming forty and something years old Franèoise, who is also having classes for her wedding party, and she recalls she was her neighbor in her childhood. They become close and love flourishes between them, changing their lives.', 'languages': ['French'], 'released': datetime.datetime(2005, 10, 12, 0, 0), 'directors': ['Stèphane Brizè'], 'writers': ['Stèphane Brizè', 'Juliette Sales'], 'awards': {'wins': 2, 'nominations': 5, 'text': '2 wins & 5 nominations.'}, 'lastupdated': '2015-08-16 01:21:30.370000000', 'year': 2005, 'imdb': {'rating': 7.2, 'votes': 1307, 'id': 436445}, 'countries': ['France'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 558}, 'lastUpdated': datetime.datetime(2015, 9, 1, 19, 33, 12)}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a13a8f29313caabd1d4a4'), 'plot': "Aaaah... it's New York City in 1962, and love is blooming between a journalist and a feminist advice author, who's falling head over heels despite her beau's playboy lifestyle.", 'genres': ['Comedy', 'Romance'], 'runtime': 101, 'metacritic': 52, 'rated': 'PG-13', 'cast': ['Renèe Zellweger', 'Ewan McGregor', 'Sarah Paulson', 'David Hyde Pierce'], 'poster': 'https://m.media-amazon.com/images/M/MV5BYjY0OTMyNmMtODEwZS00ZWJiLWI0ZjctNmNiNmJjMTMzYWM1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg', 'title': 'Down with Love', 'fullplot': 'An homage to the early 1960s sex comedies that starred Rock Hudson and Doris Day. The story follows a best-selling female advice author who has all the answers until a sly journalist playboy starts asking the questions.', 'languages': ['English'], 'released': datetime.datetime(2003, 5, 16, 0, 0), 'directors': ['Peyton Reed'], 'writers': ['Eve Ahlert', 'Dennis Drake'], 'awards': {'wins': 4, 'nominations': 7, 'text': '4 wins & 7 nominations.'}, 'lastupdated': '2015-08-29 01:02:50.420000000', 'year': 2003, 'imdb': {'rating': 6.3, 'votes': 31672, 'id': 309530}, 'countries': ['USA', 'Germany'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 64, 'meter': 50}, 'dvd': datetime.datetime(2005, 2, 15, 0, 0), 'critic': {'rating': 8.3, 'numReviews': 5, 'meter': 100}, 'lastUpdated': datetime.datetime(2015, 9, 11, 18, 50, 56), 'rotten': 0, 'fresh': 5}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a13a5f29313caabd14e36'), 'fullplot': "It's All About Love is the story of two lovers and their attempts to save their relationship in a near-future world on the brink of cosmic collapse. John, and world-famous ice skating star, Elena, are about to sign divorce papers when they realise that, in spite of everything happening around them, their love is worth fighting for. It's All About Love is a fresh take on modern love and future life as two lovers struggle in a conspiracy of epic proportions.", 'imdb': {'rating': 5.5, 'votes': 6964, 'id': 273689}, 'year': 2003, 'plot': "It's All About Love is the story of two lovers and their attempts to save their relationship in a near-future world on the brink of cosmic collapse. John, and world-famous ice skating star,...", 'genres': ['Drama', 'Thriller', 'Romance'], 'rated': 'R', 'metacritic': 32, 'title': "It's All About Love", 'lastupdated': '2015-08-12 00:00:48.250000000', 'languages': ['English'], 'writers': ['Mogens Rukov', 'Thomas Vinterberg'], 'type': 'movie', 'tomatoes': {'website': 'http://www.tvropa.com/itsallaboutlove/', 'viewer': {'rating': 2.6, 'numReviews': 1292, 'meter': 26}, 'dvd': datetime.datetime(2005, 9, 27, 0, 0), 'critic': {'rating': 3.8, 'numReviews': 29, 'meter': 14}, 'lastUpdated': datetime.datetime(2015, 8, 6, 20, 15, 18), 'rotten': 25, 'production': 'Focus Features', 'fresh': 4}, 'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzMzc1MDI3NV5BMl5BanBnXkFtZTcwNDQyMzcyMQ@@._V1_SY1000_SX677_AL_.jpg', 'num_mflix_comments': 1, 'released': datetime.datetime(2003, 1, 10, 0, 0), 'awards': {'wins': 3, 'nominations': 0, 'text': '3 wins.'}, 'countries': ['Italy', 'France', 'Canada', 'Spain', 'USA', 'Japan', 'Sweden', 'UK', 'Denmark', 'Germany', 'Netherlands'], 'cast': ['Joaquin Phoenix', 'Claire Danes', 'Sean Penn', 'Douglas Henshall'], 'directors': ['Thomas Vinterberg'], 'runtime': 104}
# {'_id': ObjectId('573a13a5f29313caabd13d25'), 'countries': ['France'], 'genres': ['Drama'], 'runtime': 90, 'cast': ['Virginie Ledoyen', 'Yazid Aèt', 'Mar Sodupe', 'Stomy Bugsy'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BMTM2NzkwMTMxOV5BMl5BanBnXkFtZTcwNjc1NDIyMQ@@._V1_SY1000_SX677_AL_.jpg', 'title': 'All About Love', 'lastupdated': '2015-07-26 00:01:56.633000000', 'languages': ['French'], 'released': datetime.datetime(2001, 4, 11, 0, 0), 'directors': ['Jean-Franèois Richet'], 'writers': ['Yazid Aèt (dialogue)', 'Jean-Franèois Richet'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'year': 2001, 'imdb': {'rating': 5.3, 'votes': 392, 'id': 269138}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 0.5, 'numReviews': 22}, 'lastUpdated': datetime.datetime(2015, 1, 24, 14, 25, 9)}}
# {'_id': ObjectId('573a139af29313caabcf0caf'), 'plot': 'Maureen is pregnant and her husband Eddie is missing. Nervous, Maureen shares a couple of drinks with neighbor Kiefer, who tries to rape her and then beats her. When Eddie returns and finds...', 'genres': ['Drama', 'Romance'], 'runtime': 100, 'rated': 'R', 'cast': ['Sean Penn', 'James Gandolfini', 'Robin Wright', 'John Travolta'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BZmU1ZTU3MDMtNTQzMy00NTU0LWFmY2EtMjgxMGM3YzBkOGFmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg', 'title': "She's So Lovely", 'fullplot': 'Maureen is pregnant and her husband Eddie is missing. Nervous, Maureen shares a couple of drinks with neighbor Kiefer, who tries to rape her and then beats her. When Eddie returns and finds his wife bruised, he goes ballistic, shoots a paramedic and is put in a psychiatric institution. Ten years later, Eddie is released and finds that Maureen has divorced him and is remarried with three children, one of whom is his little girl Jeanie. Eddie goes to reclaim his wife.', 'languages': ['English'], 'released': datetime.datetime(1997, 8, 27, 0, 0), 'directors': ['Nick Cassavetes'], 'writers': ['John Cassavetes'], 'awards': {'wins': 3, 'nominations': 3, 'text': '3 wins & 3 nominations.'}, 'lastupdated': '2015-08-21 00:13:37.470000000', 'year': 1997, 'imdb': {'rating': 5.9, 'votes': 6822, 'id': 120112}, 'countries': ['France', 'USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 5760, 'meter': 63}, 'dvd': datetime.datetime(2000, 11, 14, 0, 0), 'critic': {'rating': 6.1, 'numReviews': 41, 'meter': 66}, 'lastUpdated': datetime.datetime(2015, 8, 20, 19, 0, 17), 'rotten': 14, 'production': 'Miramax', 'fresh': 27}}
# {'_id': ObjectId('573a1398f29313caabce9ff3'), 'countries': ['France', 'Italy'], 'genres': ['Drama', 'Fantasy', 'Romance'], 'runtime': 101, 'cast': ['Christopher Lambert', 'Eddy Mitchell', 'Flora Barillaro', 'Agnès Soral'], 'poster': 'https://m.media-amazon.com/images/M/MV5BZmFjNmMzOGItYTUwNS00NTkwLWI2MTktNmRkNGIwMjQ4MDY0XkEyXkFqcGdeQXVyMjQzMzQzODY@._V1_SY1000_SX677_AL_.jpg', 'title': 'I Love You', 'lastupdated': '2015-08-27 00:08:16.557000000', 'languages': ['French'], 'released': datetime.datetime(1986, 5, 14, 0, 0), 'directors': ['Marco Ferreri'], 'writers': ['Marco Ferreri (original idea)', 'Enrico Oldoini (scenario & adaptation and dialogue)', 'Didier Kaminka (scenario & adaptation and dialogue)', 'Marco Ferreri (scenario & adaptation and dialogue)'], 'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'}, 'year': 1986, 'imdb': {'rating': 5.9, 'votes': 325, 'id': 91244}, 'type': 'movie', 'num_mflix_comments': 0}
# {'_id': ObjectId('573a1396f29313caabce40d1'), 'plot': 'Brooks Wilson is in crisis. He is torn between his wife Selma and two daughters and his mistress Grace, and also between his career as a successful illustrator and his feeling that he might...', 'genres': ['Comedy', 'Drama'], 'runtime': 89, 'rated': 'R', 'cast': ['George Segal', 'Eva Marie Saint', 'Sterling Hayden', 'Keenan Wynn'], 'poster': 'https://m.media-amazon.com/images/M/MV5BNDRjMmFiYWMtMWNlMy00NTc0LTljOWQtNWQ2MzM3YzJjZWNiXkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_SY1000_SX677_AL_.jpg', 'title': 'Loving', 'fullplot': 'Brooks Wilson is in crisis. He is torn between his wife Selma and two daughters and his mistress Grace, and also between his career as a successful illustrator and his feeling that he might still produce something worthwhile.', 'languages': ['English'], 'released': datetime.datetime(1970, 4, 27, 0, 0), 'directors': ['Irvin Kershner'], 'writers': ['Don Devlin', 'J.M. Ryan (novel)'], 'awards': {'wins': 3, 'nominations': 0, 'text': '3 wins.'}, 'lastupdated': '2015-07-13 00:22:00.747000000', 'year': 1970, 'imdb': {'rating': 6.4, 'votes': 372, 'id': 66017}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 2.7, 'numReviews': 757, 'meter': 33}, 'dvd': datetime.datetime(2003, 7, 29, 0, 0), 'production': 'Columbia Pictures', 'lastUpdated': datetime.datetime(2015, 8, 17, 18, 37, 39)}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a13fbf29313caabdedf30'), 'plot': "Guy's tragic death is a shock for the Leblanc family. For many years, the real cause of his death is kept hidden from some members of the family, including his son David. The latter in turn...", 'genres': ['Drama'], 'runtime': 102, 'cast': ['Maxim Gaudette', 'Karelle Tremblay', 'Valerie Cadieux', 'Mickael Gouin'], 'num_mflix_comments': 0, 'title': 'Our Loved Ones', 'fullplot': "Guy's tragic death is a shock for the Leblanc family. For many years, the real cause of his death is kept hidden from some members of the family, including his son David. The latter in turn starts his own family with his wife Marie. He lovingly raises his children Laurence and Frèdèric, but deep within him harbours a persistent melancholy.", 'languages': ['French'], 'released': datetime.datetime(2015, 8, 12, 0, 0), 'directors': ['Anne èmond'], 'writers': ['Anne èmond'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-08-27 00:18:43.727000000', 'year': 2015, 'imdb': {'rating': 7.4, 'votes': 5, 'id': 4881276}, 'countries': ['Canada'], 'type': 'movie'}
# {'_id': ObjectId('573a13faf29313caabdebb94'), 'plot': 'A group of women in Morocco make a living as prostitutes in a culture that is very unforgiving toward women in that profession.', 'genres': ['Drama'], 'runtime': 108, 'cast': ['Loubna Abidar', 'Danny Boushebel', 'Abdellah Didane', 'Sara Elhamdi Elalaoui'], 'title': 'Much Loved', 'fullplot': 'A group of women in Morocco make a living as prostitutes in a culture that is very unforgiving toward women in that profession.', 'languages': ['Arabic'], 'released': datetime.datetime(2015, 9, 16, 0, 0), 'directors': ['Nabil Ayouch'], 'writers': ['Nabil Ayouch'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-09-06 00:00:41.930000000', 'year': 2015, 'imdb': {'rating': 4.5, 'votes': 246, 'id': 4685750}, 'countries': ['France', 'Morocco'], 'type': 'movie', 'num_mflix_comments': 0}
# {'_id': ObjectId('573a13f4f29313caabde2d1c'), 'plot': 'Isabelle and Gèrard go to a strange appointment in Death Valley, California. They have not seen each other for years and are here to answer to an invitation from their son Michael, a ...', 'genres': ['Drama'], 'runtime': 91, 'cast': ['Gèrard Depardieu', 'Isabelle Huppert', 'Dan Warner', 'Aurèlia Thièrrèe'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BODY5Nzk1Njk3Ml5BMl5BanBnXkFtZTgwOTM5MDYxODE@._V1_SY1000_SX677_AL_.jpg', 'title': 'Valley of Love', 'fullplot': 'Isabelle and Gèrard go to a strange appointment in Death Valley, California. They have not seen each other for years and are here to answer to an invitation from their son Michael, a photographer, which they received after his suicide, six months ago.', 'languages': ['English', 'French'], 'released': datetime.datetime(2015, 6, 17, 0, 0), 'directors': ['Guillaume Nicloux'], 'writers': ['Guillaume Nicloux (screenplay)', 'David H. Pickering (translation)'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-08-18 00:01:36.047000000', 'year': 2015, 'imdb': {'rating': 6.4, 'votes': 223, 'id': 4120210}, 'countries': ['France', 'Belgium'], 'type': 'movie'}
# {'_id': ObjectId('573a13f0f29313caabdd9e0f'), 'plot': 'Autism in Love follows the story of four adults with autism spectrum disorders as they search for and manage romantic relationships.', 'genres': ['Documentary', 'Drama'], 'runtime': 76, 'title': 'Autism in Love', 'num_mflix_comments': 0, 'countries': ['USA'], 'fullplot': 'Autism in Love follows the story of four adults with autism spectrum disorders as they search for and manage romantic relationships.', 'languages': ['English'], 'released': datetime.datetime(2015, 4, 16, 0, 0), 'directors': ['Matt Fuller'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-09-11 00:42:31.980000000', 'year': 2015, 'imdb': {'rating': 7.4, 'votes': 9, 'id': 3719452}, 'type': 'movie'}
# {'_id': ObjectId('573a13ebf29313caabdd1ba8'), 'plot': 'In the 1960s and 1970s, Singaporeans, who were activists, student leaders or Communists were exiled from their country. Fifty years later, despite resettling in countries such as the United...', 'genres': ['Documentary'], 'runtime': 70, 'cast': ['Swee Chai Ang', 'Sun Wing Chan', 'Mr. & Mrs Hee Kim Tan', 'Juan Thai Ho'], 'num_mflix_comments': 0, 'title': 'To Singapore, with Love', 'fullplot': "In the 1960s and 1970s, Singaporeans, who were activists, student leaders or Communists were exiled from their country. Fifty years later, despite resettling in countries such as the United Kingdom, Malaysia and Thailand, it is clear that the diaspora still holds Singapore and the idea of returning home in their hearts and minds. TO SINGAPORE, WITH LOVE follows the exiled protagonists in the film, as they undertake a trip to Singapore's closest neighbor, Malaysia, where they attend reunions, memorials and stay in a hotel that overlooks their homeland.", 'languages': ['English', 'Malay', 'Mandarin'], 'released': datetime.datetime(2014, 4, 23, 0, 0), 'directors': ['Pin Pin Tan'], 'writers': ['Pin Pin Tan'], 'awards': {'wins': 2, 'nominations': 1, 'text': '2 wins & 1 nomination.'}, 'lastupdated': '2015-03-25 00:03:27.010000000', 'year': 2013, 'imdb': {'rating': 7.3, 'votes': 10, 'id': 3461274}, 'countries': ['Singapore'], 'type': 'movie'}
# {'_id': ObjectId('573a13e5f29313caabdc3a5b'), 'plot': "What is stranger than the big hole that opens up in Lucy Sherrington's living room floor? As it turns out, love.", 'genres': ['Comedy', 'Romance'], 'runtime': 89, 'cast': ['Alison Brie', 'Justin Chatwin', 'Colin Hanks', 'Aaron Poole'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BMjAwNzg4NjAyNV5BMl5BanBnXkFtZTgwMzgxNTM4ODE@._V1_SY1000_SX677_AL_.jpg', 'title': 'No Stranger Than Love', 'fullplot': "What is stranger than the big hole that opens up in Lucy Sherrington's living room floor? As it turns out, love.", 'languages': ['English'], 'released': datetime.datetime(2015, 4, 30, 0, 0), 'directors': ['Nick Wernham'], 'writers': ['Steve Adams'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-09-06 01:00:26.070000000', 'year': 2015, 'imdb': {'rating': 6.9, 'votes': 28, 'id': 2998406}, 'countries': ['Canada'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 4}, 'lastUpdated': datetime.datetime(2015, 9, 17, 17, 15, 41)}}
# {'_id': ObjectId('573a13e5f29313caabdc2632'), 'plot': 'Luxury hotel. Luxury clientele. Irritable staff. A couple who might fall in love, or they might leave their relationship in its raw state - like the titular steaks.', 'genres': ['Comedy', 'Drama', 'Romance'], 'runtime': 89, 'cast': ['Lana Cooper', 'Franz Rogowski'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNjQxNzkzOV5BMl5BanBnXkFtZTgwMzA5MTUzMTE@._V1_SY1000_SX677_AL_.jpg', 'title': 'Love Steaks', 'fullplot': 'A luxury hotel. Steaks frizzle, muffintops getting massaged. Clemens (rare) joins the wellness area as a rookie. Lara (well-done) needs to assert herself in the kitchen pack. The elevator brings the two of them together. Hanging in dependence. They encounter each other, until they clash.', 'languages': ['German'], 'released': datetime.datetime(2014, 3, 27, 0, 0), 'directors': ['Jakob Lass'], 'writers': ['Jakob Lass (screenplay)', 'Ines Schiller (screenplay)', 'Timon Schaeppi (screenplay)', 'Nico Woche (screenplay)', 'Timon Schaeppi', 'Jakob Lass', 'Nico Woche', 'Ines Schiller'], 'awards': {'wins': 9, 'nominations': 4, 'text': '9 wins & 4 nominations.'}, 'lastupdated': '2015-08-16 00:34:33.963000000', 'year': 2013, 'imdb': {'rating': 6.8, 'votes': 491, 'id': 2960270}, 'countries': ['Germany'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 11}, 'lastUpdated': datetime.datetime(2015, 7, 30, 19, 8, 31)}}
# {'_id': ObjectId('573a13e2f29313caabdbdd70'), 'plot': 'Love Building is a camp designed to mend broken relationships. 14 couples in the program have 7 days to re-design their love lives. But the 3 trainers meant to assist them have problems of their own and things gradually get out of hand.', 'genres': ['Comedy'], 'runtime': 85, 'cast': ['Dorian Boguta', 'Dragos Bucur', 'Eugen Lumezianu', 'Silvia Morosanu'], 'num_mflix_comments': 1, 'title': 'Love Building', 'fullplot': 'Love Building is a camp designed to mend broken relationships. 14 couples in the program have 7 days to re-design their love lives. But the 3 trainers meant to assist them have problems of their own and things gradually get out of hand.', 'languages': ['Romanian'], 'released': datetime.datetime(2013, 9, 13, 0, 0), 'directors': ['Iulia Rugina'], 'writers': ['Ana Agopian', 'Oana Rasuceanu', 'Iulia Rugina'], 'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'}, 'lastupdated': '2015-05-19 02:26:26.467000000', 'year': 2013, 'imdb': {'rating': 7.1, 'votes': 388, 'id': 2792332}, 'countries': ['Romania'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 9}, 'lastUpdated': datetime.datetime(2015, 6, 26, 20, 23, 45)}}
# {'_id': ObjectId('573a13e1f29313caabdbd01e'), 'plot': "A family man's encounter with a beautiful woman develops into a mutual fascination.", 'genres': ['Drama', 'Romance'], 'runtime': 81, 'cast': ['Sophie Marceau', 'Franèois Cluzet', 'Lisa Azuelos', 'Alexandre Astier'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BZDZlOTQ2NmMtYzE0OS00M2RkLThlZjgtMmE1OGM5NTc4YjA1XkEyXkFqcGdeQXVyMjQzMzQzODY@._V1_SY1000_SX677_AL_.jpg', 'title': 'Quantum Love', 'fullplot': "A family man's encounter with a beautiful woman develops into a mutual fascination.", 'languages': ['French', 'English'], 'released': datetime.datetime(2014, 4, 23, 0, 0), 'directors': ['Lisa Azuelos'], 'writers': ['Lisa Azuelos'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-08-15 00:55:06.147000000', 'year': 2014, 'imdb': {'rating': 6.3, 'votes': 1395, 'id': 2760634}, 'countries': ['France'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 86}, 'production': 'Bethsabèe Mucho', 'lastUpdated': datetime.datetime(2015, 8, 16, 19, 10, 52)}}
# {'_id': ObjectId('573a13e1f29313caabdbce64'), 'fullplot': 'Struggling with a marriage on the brink of falling apart, a couple escapes for a weekend in pursuit of their better selves, only to discover an unusual dilemma that awaits them.', 'imdb': {'rating': 7.1, 'votes': 17753, 'id': 2756032}, 'year': 2014, 'plot': 'Struggling with a marriage on the brink of falling apart, a couple escapes for a weekend in pursuit of their better selves, only to discover an unusual dilemma that awaits them.', 'genres': ['Comedy', 'Drama', 'Romance'], 'rated': 'R', 'metacritic': 66, 'title': 'The One I Love', 'lastupdated': '2015-09-05 00:01:12.627000000', 'languages': ['English'], 'writers': ['Justin Lader'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 8576, 'meter': 76}, 'dvd': datetime.datetime(2014, 11, 3, 0, 0), 'critic': {'rating': 7.0, 'numReviews': 81, 'meter': 80}, 'boxOffice': '$0.5M', 'consensus': "The One I Love doesn't take its intriguing premise quite as far as it could, but it still adds up to an ambitious, well-acted look at love and marriage.", 'rotten': 16, 'production': 'Radius-TWC', 'lastUpdated': datetime.datetime(2015, 9, 13, 18, 4, 38), 'fresh': 65}, 'poster': 'https://m.media-amazon.com/images/M/MV5BMTgzODMyMjcyOV5BMl5BanBnXkFtZTgwMTAyMjMyMjE@._V1_SY1000_SX677_AL_.jpg', 'num_mflix_comments': 0, 'released': datetime.datetime(2014, 8, 8, 0, 0), 'awards': {'wins': 2, 'nominations': 2, 'text': '2 wins & 2 nominations.'}, 'countries': ['USA'], 'cast': ['Mark Duplass', 'Elisabeth Moss', 'Ted Danson', 'Kiana Cason'], 'directors': ['Charlie McDowell'], 'runtime': 91}
# {'_id': ObjectId('573a13e0f29313caabdbb029'), 'plot': 'Lovers start games.', 'genres': ['Animation', 'Short', 'Drama'], 'runtime': 15, 'title': 'Love Games', 'num_mflix_comments': 1, 'countries': ['South Korea'], 'fullplot': 'Lovers start games.', 'languages': ['English'], 'released': datetime.datetime(2013, 2, 10, 0, 0), 'directors': ['Joung Yumi'], 'writers': ['Joung Yumi'], 'awards': {'wins': 0, 'nominations': 3, 'text': '3 nominations.'}, 'lastupdated': '2015-08-29 00:16:38.750000000', 'year': 2012, 'imdb': {'rating': 7.0, 'votes': 26, 'id': 2671600}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 2.5, 'numReviews': 3}, 'lastUpdated': datetime.datetime(2015, 8, 20, 18, 41, 3)}}
# {'_id': ObjectId('573a13e0f29313caabdba100'), 'plot': 'After Ben and George get married, George is fired from his teaching post, forcing them to stay with friends separately while they sell their place and look for cheaper housing -- a situation that weighs heavily on all involved.', 'genres': ['Drama'], 'runtime': 94, 'metacritic': 82, 'rated': 'R', 'cast': ['John Lithgow', 'Alfred Molina', 'Tatyana Zbirovskaya', 'Olya Zueva'], 'poster': 'https://m.media-amazon.com/images/M/MV5BMTk5MTkxOTI1N15BMl5BanBnXkFtZTgwNzAwNDA4MTE@._V1_SY1000_SX677_AL_.jpg', 'title': 'Love Is Strange', 'fullplot': 'After nearly four decades together, Ben (John Lithgow) and George (Alfred Molina) finally tie the knot in an idyllic wedding ceremony in lower Manhattan. But when George loses his job soon after, the couple must sell their apartment and - victims of the relentless New York City real estate market - temporarily live apart until they can find an affordable new home. While George moves in with two cops (Cheyenne Jackson and Manny Perez) who live down stairs, Ben lands in Brooklyn with his nephew (Darren Burrows), his wife (Marisa Tomei), and their temperamental teenage son (Charlie Tahan), with whom Ben shares a bunk bed. While struggling with the pain of separation, Ben and George are further challenged by the intergenerational tensions and capricious family dynamics of their new living arrangements.', 'languages': ['English', 'Russian'], 'released': datetime.datetime(2014, 11, 12, 0, 0), 'directors': ['Ira Sachs'], 'writers': ['Ira Sachs', 'Mauricio Zacharias'], 'awards': {'wins': 1, 'nominations': 15, 'text': '1 win & 15 nominations.'}, 'lastupdated': '2015-09-10 17:08:56.030000000', 'year': 2014, 'imdb': {'rating': 6.7, 'votes': 7548, 'id': 2639344}, 'countries': ['USA', 'France', 'Brazil', 'Greece'], 'type': 'movie', 'tomatoes': {'website': 'http://loveisstrangemovie.com/', 'viewer': {'rating': 3.5, 'numReviews': 12521, 'meter': 66}, 'dvd': datetime.datetime(2015, 1, 13, 0, 0), 'critic': {'rating': 7.8, 'numReviews': 154, 'meter': 94}, 'boxOffice': '$2.3M', 'consensus': 'Held aloft by remarkable performances from John Lithgow and Alfred Molina, Love Is Strange serves as a graceful tribute to the beauty of commitment in the face of adversity.', 'rotten': 9, 'production': 'Sony Pictures Classics', 'lastUpdated': datetime.datetime(2015, 8, 18, 18, 9, 31), 'fresh': 145}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a13e0f29313caabdb9eb5'), 'plot': 'A lesbian with commitment issues befriends a widowed mother who is visiting her workaholic daughter.', 'genres': ['Drama', 'Romance'], 'runtime': 94, 'cast': ['Kate Trotter', 'Peter MacNeill', 'Shauna MacDonald', 'Anna Cyzon'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BMjMzMDYyODIyOF5BMl5BanBnXkFtZTgwODAxMjIzMDE@._V1_SY1000_SX677_AL_.jpg', 'title': 'Tru Love', 'fullplot': "TRU, 37, is a serial bed-hopping lesbian who cannot commit to a relationship or a job for long...that is, until she meets ALICE, 60, a beautiful widow, who has come to town at the last minute to visit her daughter, SUZANNE, 35, a too-busy corporate lawyer and Tru's friend. Alice and Tru begin to forge an unlikely friendship...and more. Suzanne, who has a deeply conflicted relationship with her mother and a complicated past with Tru, becomes increasingly alarmed at the growing bond between Tru and her mother. Tensions escalate after Suzanne witnesses an intimate moment between them. She tries to sabotage the budding romance, but it backfires, as Tru Love is hard to contain.", 'languages': ['English'], 'released': datetime.datetime(2014, 4, 10, 0, 0), 'directors': ['Kate Johnston', 'Shauna MacDonald'], 'writers': ['Kate Johnston', 'Shauna MacDonald'], 'awards': {'wins': 10, 'nominations': 1, 'text': '10 wins & 1 nomination.'}, 'lastupdated': '2015-08-31 00:23:57.670000000', 'year': 2013, 'imdb': {'rating': 6.7, 'votes': 199, 'id': 2634384}, 'countries': ['Canada'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 57, 'meter': 71}, 'dvd': datetime.datetime(2014, 11, 4, 0, 0), 'website': 'http://trulovethefilm.com/', 'production': 'Indiecan Entertainment', 'lastUpdated': datetime.datetime(2015, 9, 13, 18, 12, 59)}}
# {'_id': ObjectId('573a13def29313caabdb6eae'), 'plot': 'Kertu s life is totally spoiled by an overbearing father, until she opens her heart to an unlikely dream lover.', 'genres': ['Drama', 'Romance'], 'runtime': 98, 'cast': ['Jèri Lumiste', 'Mait Malmsten', 'Ursula Ratasepp', 'Kèlliki Saldre'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BNGE2YjVhM2QtOTg4ZC00MDczLTkzMTItZTYwNDU0ZjcxYmRmXkEyXkFqcGdeQXVyMTc4MzI2NQ@@._V1_SY1000_SX677_AL_.jpg', 'title': 'Love Is Blind', 'fullplot': "30-year old Kertu has lived under her father's power her whole life. Because of her gentle nature, she is thought by locals to be a little simple-minded. The young woman makes her first timid attempt to change something in her life - she send a postcard to Villu, a handsome but degenerate village drunk.", 'languages': ['Estonian'], 'released': datetime.datetime(2013, 10, 11, 0, 0), 'directors': ['Ilmar Raag'], 'writers': ['Ilmar Raag'], 'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'}, 'lastupdated': '2015-08-09 00:58:19.880000000', 'year': 2013, 'imdb': {'rating': 7.5, 'votes': 595, 'id': 2534648}, 'countries': ['Estonia'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 11}, 'lastUpdated': datetime.datetime(2015, 8, 8, 18, 45, 9)}}
# ...
# {'_id': ObjectId('573a139af29313caabcefba9'), 'plot': "Two young people meet in the 60's as a result of their devotion to John Lennon, and have a recurring relationship during the next thirty years at the oddest of moments, in the most diverse ...", 'genres': ['Comedy', 'Romance'], 'runtime': 117, 'cast': ['Ana Belèn', 'Juanjo Puigcorbè', 'Gabino Diego', 'Penèlope Cruz'], 'poster': 'https://m.media-amazon.com/images/M/MV5BY2EwMGZkNWYtM2Y4MC00ZTAyLWFkYmMtMzc0NGQxNWRhZjhjXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_SY1000_SX677_AL_.jpg', 'title': 'Love Can Seriously Damage Your Health', 'fullplot': "Two young people meet in the 60's as a result of their devotion to John Lennon, and have a recurring relationship during the next thirty years at the oddest of moments, in the most diverse places, and during very important moments that defined several decades. Pay attention as one couple of younger actors alternate with the other couple of older actors to recreate this 30 year span in this Spanish-French comedy.", 'languages': ['Spanish'], 'released': datetime.datetime(1997, 1, 10, 0, 0), 'directors': ['Manuel Gèmez Pereira'], 'writers': ['Yolanda Garcèa Serrano', 'Manuel Gèmez Pereira', 'Juan Luis Iborra', 'Joaquèn Oristrell'], 'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'}, 'lastupdated': '2015-07-29 00:49:09.207000000', 'year': 1996, 'imdb': {'rating': 6.8, 'votes': 1253, 'id': 115536}, 'countries': ['Spain', 'France'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 783, 'meter': 72}, 'dvd': datetime.datetime(2001, 10, 23, 0, 0), 'production': 'Andale Pictures', 'lastUpdated': datetime.datetime(2015, 8, 5, 19, 38, 28)}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a13a6f29313caabd18ca4'), 'plot': "Shekhar accidentally kills his associate Amar, and decides to watch over Amar's company and take care of his family and friends. However, he falls in love with Amar's fiancè Piya.", 'genres': ['Drama', 'Romance'], 'countries': ['India'], 'cast': ['Priyanshu Chatterjee', 'Himanshu Malik', 'Sandali Sinha', 'Raqesh Vashisth'], 'num_mflix_comments': 0, 'title': 'Tum Bin...: Love Will Find a Way', 'fullplot': "Shekhar is a qualified businees professional in India. One day, he meets Amar, chairman of Shah Industries of Canada. Amar is impressed with Shekhar's professionalism and qualifications and that is why he offers him to work with him in Canada. But accidently, on the same evening, Amar gets killed by Shekhar's car. In order to keep off his guilt, he goes to Canada and helps the troubled Shah Indurtries to rise and during the way falls in love with Pia, Amar's fiance. Then there is Abhay, another businessman, who also falls in love with Pia. Ultimately, Pia comes to know that Amar got killed due to Shekhar, but forgives him.", 'languages': ['Hindi'], 'released': datetime.datetime(2001, 7, 13, 0, 0), 'directors': ['Anubhav Sinha'], 'writers': ['Shashank Dabral (screenplay)', 'Anubhav Sinha (dialogue)'], 'awards': {'wins': 0, 'nominations': 6, 'text': '6 nominations.'}, 'lastupdated': '2015-07-14 00:00:22.223000000', 'year': 2001, 'imdb': {'rating': 7.4, 'votes': 1816, 'id': 290326}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 687, 'meter': 93}, 'dvd': datetime.datetime(2001, 8, 1, 0, 0), 'lastUpdated': datetime.datetime(2015, 8, 12, 18, 29)}}
# {'_id': ObjectId('573a13a6f29313caabd18255'), 'plot': 'Prakash (Saif Ali Khan) is a handsome gold digger who thinks he has made it when he woos and subsequently marries Sapna (Sonali Bendre) , only daughter of a rich businessman Mr. Chopra (...', 'genres': ['Comedy', 'Crime', 'Romance'], 'countries': ['India'], 'cast': ['Saif Ali Khan', 'Fardeen Khan', 'Aftab Shivdasani', 'Sonali Bendre'], 'num_mflix_comments': 0, 'title': 'Love Ke Liye Kuch Bhi Karega', 'fullplot': "Prakash (Saif Ali Khan) is a handsome gold digger who thinks he has made it when he woos and subsequently marries Sapna (Sonali Bendre) , only daughter of a rich businessman Mr. Chopra (Dalip Tahil) . However his euphoria is short-lived when he learns that his father-in-law disapproves of him immensely and won't let him make his mark in the business . Finally , Prakash asks Mr.Chopra for some money to start a business of his own but Mr. Chopra refuses . One night , two masked men try to rob Prakash and he places a plan before the duo : they will kidnap Sapna and demand ransom from Mr. Chopra , which will be equally shared between Prakash and the two kidnappers - Rahul (Fardeen Khan) and Harry (Aftab Shivdasani) . Rahul and Harry have a little secret of their own : they are not professional criminals as they pretend to be . Rahul is an unemployed graduate , while Harry is a loafer . Rahul is in love with his landlord's daughter Anjali (Twinkle Khanna) and needs the money to convince her father for their marriage .", 'languages': ['Hindi', 'Telugu'], 'released': datetime.datetime(2001, 6, 29, 0, 0), 'directors': ['Eeshwar Nivas'], 'writers': ['Rajnish Thakur'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-09-06 00:44:28.103000000', 'year': 2001, 'imdb': {'rating': 6.1, 'votes': 1024, 'id': 287537}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.1, 'numReviews': 679, 'meter': 39}, 'dvd': datetime.datetime(2001, 8, 1, 0, 0), 'lastUpdated': datetime.datetime(2015, 9, 16, 17, 0, 51)}}
# {'_id': ObjectId('573a139af29313caabcef399'), 'plot': 'An adventurous love story between two young women of different social and economic backgrounds who find themselves going through all the typical struggles of a new romance.', 'genres': ['Comedy', 'Drama', 'Romance'], 'runtime': 94, 'rated': 'R', 'cast': ['Laurel Holloman', 'Maggie Moore', 'Kate Stafford', 'Sabrina Artel'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BY2EyYzgxOWEtMWM4Ni00MmYzLTljZDYtMTVjYTQzZTlmMDdjXkEyXkFqcGdeQXVyMTQ4NDY5OTc@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Incredibly True Adventure of Two Girls in Love', 'fullplot': "The story of two girls, Randy and Evie. Randy is a low economic class lesbian living with other lesbians including her aunt. Evie is a wealthy, popular girl with a boyfriend. When Evie befriends Randy, she begins to feel a passion for her she's never felt before. What follows is a sweet, tender romance between the two while Evie is cast away by her friends and Randy is chided by her family. The two don't care, though, because they are in love.", 'languages': ['English'], 'released': datetime.datetime(1995, 6, 16, 0, 0), 'directors': ['Maria Maggenti'], 'writers': ['Maria Maggenti'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-08-18 00:25:41.233000000', 'year': 1995, 'imdb': {'rating': 6.5, 'votes': 3292, 'id': 113416}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'website': 'http://www.wbshop.com/', 'viewer': {'rating': 3.5, 'numReviews': 6419, 'meter': 68}, 'dvd': datetime.datetime(2004, 5, 4, 0, 0), 'critic': {'rating': 6.5, 'numReviews': 9, 'meter': 67}, 'lastUpdated': datetime.datetime(2015, 5, 11, 19, 22, 43), 'rotten': 3, 'production': 'WARNER BROTHERS PICTURES', 'fresh': 6}}
# {'_id': ObjectId('573a1398f29313caabcebbca'), 'plot': 'A man travels from China to Vietnam, on the brink of war with America, to retrieve his uncle and cousin but find complications when he falls in love with a female gangster with a dangerous ex.', 'genres': ['Action', 'War'], 'runtime': 105, 'rated': 'R', 'cast': ['Yun-Fat Chow', 'Tony Ka Fai Leung', 'Anita Mui', 'Kien Shih'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BMTc4Nzc3MDU2Ml5BMl5BanBnXkFtZTcwNjAyODgxMQ@@._V1_SY1000_SX677_AL_.jpg', 'title': 'A Better Tomorrow III: Love and Death in Saigon', 'fullplot': "At the end of the Vietnam war, Cheung goes to Saigon, intent on bringing his uncle and cousin back to Hong Kong. In Saigon, Cheung meets beautiful gangleader Chow, and relies on her help for their safe return. A love triangle develops between the cousins and Chow Further complicating matters, Chow's lover Ho, a gang leader, appears Ho deports the cousins, and kills their uncle. Cheung and his cousin return to Vietnam seeking revenge, while Chow and Ho also become entangled with a local vietnamese warlord. Chow tries to stop the battle, but the warlord kills Chow and Ho. Just before her death Chow gives the cousins the last two air tickets with which to leave Vietnam", 'languages': ['Cantonese', 'English', 'Vietnamese'], 'released': datetime.datetime(1989, 10, 20, 0, 0), 'directors': ['Hark Tsui'], 'writers': ['Yiu Ming Leung (screenplay)', 'Foo Ho Tai (screenplay)', 'Hark Tsui'], 'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'}, 'lastupdated': '2015-09-15 03:33:59.630000000', 'year': 1989, 'imdb': {'rating': 5.9, 'votes': 2170, 'id': 98691}, 'countries': ['Hong Kong'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 5894, 'meter': 35}, 'dvd': datetime.datetime(2000, 2, 22, 0, 0), 'lastUpdated': datetime.datetime(2015, 8, 9, 19, 32, 3)}}
# {'_id': ObjectId('573a13b6f29313caabd4842b'), 'plot': "Welcome to The Great Happiness Space: Rakkyo Cafè. The club's owner, Issei (22), has a staff of twenty boys all under his training to become the top escorts of Osaka's underground love ...", 'genres': ['Documentary'], 'runtime': 76, 'title': 'The Great Happiness Space: Tale of an Osaka Love Thief', 'countries': ['USA'], 'fullplot': "Welcome to The Great Happiness Space: Rakkyo Cafè. The club's owner, Issei (22), has a staff of twenty boys all under his training to become the top escorts of Osaka's underground love scene. During their training, they learn how to dress, how to talk, how to walk, and most importantly, how to fake relationships with the girls who become their source of income. Join us as Osaka's number one host boy takes us on a journey through the complex and heartrenching world of love for sale in the Japanese underground.", 'languages': ['Japanese', 'English'], 'released': datetime.datetime(2006, 1, 22, 0, 0), 'directors': ['Jake Clennell'], 'awards': {'wins': 1, 'nominations': 3, 'text': '1 win & 3 nominations.'}, 'lastupdated': '2015-09-14 07:21:28.433000000', 'year': 2006, 'imdb': {'rating': 7.9, 'votes': 1195, 'id': 493420}, 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 1608, 'meter': 88}, 'dvd': datetime.datetime(2007, 8, 13, 0, 0), 'lastUpdated': datetime.datetime(2015, 6, 7, 18, 11, 38)}, 'num_mflix_comments': 0}
# {'_id': ObjectId('573a1395f29313caabce1f02'), 'fullplot': 'Paranoid Brigadier General Jack D. Ripper of Burpelson Air Force Base, he believing that fluoridation of the American water supply is a Soviet plot to poison the U.S. populace, is able to deploy through a back door mechanism a nuclear attack on the Soviet Union without the knowledge of his superiors, including the Chair of the Joint Chiefs of Staff, General Buck Turgidson, and President Merkin Muffley. Only Ripper knows the code to recall the B-52 bombers and he has shut down communication in and out of Burpelson as a measure to protect this attack. Ripper\'s executive officer, RAF Group Captain Lionel Mandrake (on exchange from Britain), who is being held at Burpelson by Ripper, believes he knows the recall codes if he can only get a message to the outside world. Meanwhile at the Pentagon War Room, key persons including Muffley, Turgidson and nuclear scientist and adviser, a former Nazi named Dr. Strangelove, are discussing measures to stop the attack or mitigate its blow-up into an all out nuclear war with the Soviets. Against Turgidson\'s wishes, Muffley brings Soviet Ambassador Alexi de Sadesky into the War Room, and get his boss, Soviet Premier Dimitri Kisov, on the hot line to inform him of what\'s going on. The Americans in the War Room are dismayed to learn that the Soviets have a yet as unannounced Doomsday Device to detonate if any of their key targets are hit. As Ripper, Mandrake and those in the War Room try and work the situation to their end goal, Major T.J. "King" Kong, one of the B-52 bomber pilots, is working on his own agenda of deploying his bomb where ever he can on enemy soil if he can\'t make it to his intended target.', 'imdb': {'rating': 8.5, 'votes': 312300, 'id': 57012}, 'year': 1964, 'plot': 'An insane general triggers a path to nuclear holocaust that a war room full of politicians and generals frantically try to stop.', 'genres': ['Comedy', 'War'], 'rated': 'PG', 'metacritic': 96, 'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'lastupdated': '2015-09-07 00:02:44.187000000', 'languages': ['English', 'Russian'], 'writers': ['Stanley Kubrick (screenplay)', 'Terry Southern (screenplay)', 'Peter George (screenplay)', 'Peter George (based on the book: "Red Alert" by)'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 205971, 'meter': 94}, 'dvd': datetime.datetime(2004, 11, 2, 0, 0), 'critic': {'rating': 9.0, 'numReviews': 68, 'meter': 99}, 'lastUpdated': datetime.datetime(2015, 9, 13, 17, 1, 26), 'consensus': "Stanley Kubrick's brilliant Cold War satire remains as funny and razor-sharp today as it was in 1964.", 'rotten': 1, 'production': 'Sony Pictures', 'fresh': 67}, 'poster': 'https://m.media-amazon.com/images/M/MV5BZWI3ZTMxNjctMjdlNS00NmUwLWFiM2YtZDUyY2I3N2MxYTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg', 'num_mflix_comments': 1, 'released': datetime.datetime(1964, 1, 29, 0, 0), 'awards': {'wins': 19, 'nominations': 4, 'text': 'Nominated for 4 Oscars. Another 15 wins & 4 nominations.'}, 'countries': ['USA', 'UK'], 'cast': ['Peter Sellers', 'George C. Scott', 'Sterling Hayden', 'Keenan Wynn'], 'directors': ['Stanley Kubrick'], 'runtime': 95}
# {'_id': ObjectId('573a13c1f29313caabd642ea'), 'plot': 'She was beautiful, smart, and searching. He was an emerging genius in the world of photography. When they met, they fell instantly in love. Setting off across the West with camera and ...', 'genres': ['Documentary', 'Biography'], 'runtime': 57, 'cast': ['Christine Bernsten', 'Eric DiIlio', 'Frank DiMarco', 'Jason T. Edwards'], 'num_mflix_comments': 1, 'title': 'Eloquent Nude: The Love and Legacy of Edward Weston & Charis Wilson', 'fullplot': 'She was beautiful, smart, and searching. He was an emerging genius in the world of photography. When they met, they fell instantly in love. Setting off across the West with camera and typewriter in the depths of the Great Depression, Charis Wilson and Edward Weston transformed photography, and each other. Now age 90, Charis Wilson recounts her years with Weston with great humor, candor, and some regret. Combining insight from leading scholars, rare archival images, and convincingly authentic reenactments, Eloquent Nude presents a remarkable true story of love and loss, travel and adventure, and an intimate look at the making of Modern photography.', 'languages': ['English'], 'released': datetime.datetime(2007, 10, 27, 0, 0), 'directors': ['Ian McCluskey'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-09-13 14:11:00.120000000', 'year': 2007, 'imdb': {'rating': 8.3, 'votes': 38, 'id': 1204893}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 243}, 'lastUpdated': datetime.datetime(2015, 7, 28, 18, 35, 34)}}

# %%
#2
war_movies = collection.find({"$text": {"$search": "war"}}).sort("imdb.rating", -1).limit(5)

for movie in war_movies:
    print(movie)
# Out:
# {'_id': ObjectId('573a13f2f29313caabddcf5f'), 'plot': "Company commander Claus M. Pedersen (Pilou Asbèk) and his men are stationed in an Afghan province. Meanwhile back in Denmark Claus' wife Maria (Tuva Novotny) is trying to hold everyday life...", 'genres': ['Drama', 'War'], 'countries': ['Denmark'], 'cast': ['Pilou Asbèk', 'Tuva Novotny', 'Sèren Malling', 'Dar Salim'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BMjA1ODY3NjQzNV5BMl5BanBnXkFtZTgwNjEzNTUxNzE@._V1_SY1000_SX677_AL_.jpg', 'title': 'A War', 'fullplot': "Company commander Claus M. Pedersen (Pilou Asbèk) and his men are stationed in an Afghan province. Meanwhile back in Denmark Claus' wife Maria (Tuva Novotny) is trying to hold everyday life together with a husband at war and three children missing their father. During a routine mission, the soldiers are caught in heavy crossfire and in order to save his men, Claus makes a decision that has grave consequences for him - and his family back home.", 'languages': ['Danish'], 'released': datetime.datetime(2015, 9, 10, 0, 0), 'directors': ['Tobias Lindholm'], 'writers': ['Tobias Lindholm'], 'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'}, 'lastupdated': '2015-09-05 00:28:23.783000000', 'year': 2015, 'imdb': {'rating': '', 'votes': '', 'id': 3830162}, 'type': 'movie'}
# {'_id': ObjectId('573a13a3f29313caabd0e77b'), 'plot': 'A comprehensive survey of the American Civil War.', 'genres': ['Documentary', 'History', 'War'], 'runtime': 680, 'cast': ['Sam Waterston', 'Julie Harris', 'Jason Robards', 'Morgan Freeman'], 'num_mflix_comments': 0, 'poster': 'https://m.media-amazon.com/images/M/MV5BZDc1NzI2MGEtZDA2Yy00ZWExLTgwYmItNjU3N2QyYmM0MzYwXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Civil War', 'fullplot': "This highly acclaimed mini series traces the course of the U.S. Civil War from the abolitionist movement through all the major battles to the death of President Lincoln and the beginnings of Reconstruction. The story is mostly told in the words of the participants themselves, through their diaries, letters, and Visuals are usually still photographs and illustrations of the time, and the soundtrack is likewise made up of war-era tunes played on period instruments. Several modern-day historians offer periodic comment and insight on the war's causes and events.", 'languages': ['English'], 'released': datetime.datetime(1990, 9, 23, 0, 0), 'awards': {'wins': 10, 'nominations': 3, 'text': 'Won 2 Primetime Emmys. Another 8 wins & 3 nominations.'}, 'lastupdated': '2015-08-30 22:52:05.467000000', 'year': 1990, 'imdb': {'rating': 9.4, 'votes': 4624, 'id': 98769}, 'countries': ['USA'], 'type': 'series'}
# {'_id': ObjectId('573a1398f29313caabcebc0b'), 'plot': 'A comprehensive survey of the American Civil War.', 'genres': ['Documentary', 'History', 'War'], 'runtime': 680, 'cast': ['Sam Waterston', 'Julie Harris', 'Jason Robards', 'Morgan Freeman'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BZDc1NzI2MGEtZDA2Yy00ZWExLTgwYmItNjU3N2QyYmM0MzYwXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Civil War', 'fullplot': "This highly acclaimed mini series traces the course of the U.S. Civil War from the abolitionist movement through all the major battles to the death of President Lincoln and the beginnings of Reconstruction. The story is mostly told in the words of the participants themselves, through their diaries, letters, and Visuals are usually still photographs and illustrations of the time, and the soundtrack is likewise made up of war-era tunes played on period instruments. Several modern-day historians offer periodic comment and insight on the war's causes and events.", 'languages': ['English'], 'released': datetime.datetime(1990, 9, 23, 0, 0), 'awards': {'wins': 10, 'nominations': 3, 'text': 'Won 2 Primetime Emmys. Another 8 wins & 3 nominations.'}, 'lastupdated': '2015-09-01 00:13:15.693000000', 'year': 1990, 'imdb': {'rating': 9.4, 'votes': 4625, 'id': 98769}, 'countries': ['USA'], 'type': 'series', 'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 466, 'meter': 56}, 'dvd': datetime.datetime(2006, 1, 10, 0, 0), 'production': 'Pet Fly Productions', 'lastUpdated': datetime.datetime(2015, 8, 25, 19, 21, 52)}}
# {'_id': ObjectId('573a13bdf29313caabd5867a'), 'plot': 'A seven-part series focusing on the many ways in which the Second World War impacted the lives of American families.', 'genres': ['Documentary', 'War'], 'runtime': 124, 'cast': ['Keith David', 'Katharine Phillips', 'Tom Hanks', 'Paul Fussell'], 'num_mflix_comments': 2, 'poster': 'https://m.media-amazon.com/images/M/MV5BMTUzOTgzMzEzMF5BMl5BanBnXkFtZTgwMjIxNTcwMzE@._V1_SY1000_SX677_AL_.jpg', 'title': 'The War', 'fullplot': 'A seven-part series focusing on the many ways in which the Second World War impacted the lives of American families.', 'languages': ['English'], 'released': datetime.datetime(2007, 9, 23, 0, 0), 'rated': 'TV-14', 'awards': {'wins': 6, 'nominations': 11, 'text': 'Won 3 Primetime Emmys. Another 3 wins & 11 nominations.'}, 'lastupdated': '2015-08-24 00:14:07.227000000', 'year': 2007, 'imdb': {'rating': 9.0, 'votes': 2519, 'id': 996994}, 'countries': ['USA'], 'type': 'series', 'tomatoes': {'viewer': {'rating': 4.7, 'numReviews': 43}, 'production': 'PBS', 'lastUpdated': datetime.datetime(2015, 8, 5, 18, 1, 31)}}
# {'_id': ObjectId('573a1397f29313caabce77d9'), 'fullplot': 'After the Rebel base on the icy planet Hoth is taken over by the empire, Han, Leia, Chewbacca, and C-3PO flee across the galaxy from the Empire. Luke travels to the forgotten planet of Dagobah to receive training from the Jedi master Yoda, while Vader endlessly pursues him.', 'imdb': {'rating': 8.8, 'votes': 709821, 'id': 80684}, 'year': 1980, 'plot': 'After the rebels have been brutally overpowered by the Empire on their newly established base, Luke Skywalker takes advanced Jedi training with Master Yoda, while his friends are pursued by Darth Vader as part of his plan to capture Luke.', 'genres': ['Action', 'Adventure', 'Fantasy'], 'rated': 'PG', 'metacritic': 79, 'title': 'Star Wars: Episode V - The Empire Strikes Back', 'lastupdated': '2015-09-07 00:05:07.903000000', 'languages': ['English'], 'writers': ['Leigh Brackett (screenplay)', 'Lawrence Kasdan (screenplay)', 'George Lucas (story)'], 'type': 'movie', 'tomatoes': {'website': 'http://www.starwars.com/episode-v/', 'viewer': {'rating': 4.1, 'numReviews': 1042729, 'meter': 97}, 'dvd': datetime.datetime(2004, 9, 21, 0, 0), 'critic': {'rating': 8.9, 'numReviews': 81, 'meter': 95}, 'lastUpdated': datetime.datetime(2015, 9, 12, 17, 4, 5), 'consensus': 'Dark, sinister, but ultimately even more involving than A New Hope, The Empire Strikes Back defies viewer expectations and takes the series to heightened emotional levels.', 'rotten': 4, 'production': 'Twentieth Century Fox', 'fresh': 77}, 'poster': 'https://m.media-amazon.com/images/M/MV5BYmU1NDRjNDgtMzhiMi00NjZmLTg5NGItZDNiZjU5NTU4OTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg', 'num_mflix_comments': 115, 'released': datetime.datetime(1980, 6, 20, 0, 0), 'awards': {'wins': 16, 'nominations': 17, 'text': 'Won 1 Oscar. Another 15 wins & 17 nominations.'}, 'countries': ['USA'], 'cast': ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher', 'Billy Dee Williams'], 'directors': ['Irvin Kershner'], 'runtime': 124}

# %% [markdown]
# exercise 6

# %%
#1
action_high_rated_movies = collection.find({
    "genres": "Action",
    "imdb.rating": {"$gt": 8}
}).sort("year", -1).limit(5)

for movie in action_high_rated_movies:
  pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13bef29313caabd5b166'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Vladimir Mashkov',
#           'Mikhail Porechenkov',
#           'Vladimir Menshov',
#           'Sergey Makovetskiy'],
#  'countries': ['Russia'],
#  'genres': ['Action', 'Thriller'],
#  'imdb': {'id': 1048097, 'rating': 8.6, 'votes': 929},
#  'languages': ['Russian', 'Ukrainian'],
#  'lastupdated': '2015-04-08 00:08:01.207000000',
#  'num_mflix_comments': 1,
#  'released': datetime.datetime(2007, 12, 2, 0, 0),
#  'runtime': 45,
#  'title': 'Liquidation',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 17, 10, 27),
#               'viewer': {'meter': 23, 'numReviews': 83, 'rating': 1.9}},
#  'type': 'series',
#  'year': '2007è'}
# {'_id': ObjectId('573a13bdf29313caabd586eb'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Katie Gray', 'Victoria Harwood', 'Crispin Freeman', 'Ralph Lister'],
#  'countries': ['Japan'],
#  'fullplot': 'In flashback, Integra is seen assuming leadership of the '
#              'Hellsing organization as she resolves a conflict with her uncle '
#              'with the help of the vampire Alucard. In present day, Alucard '
#              'goes on a mission to the town of Cheddar to silence a vampiric '
#              'priest who has been killing townspeople, and in the process must '
#              'also present the young police girl Seras Victoria with the '
#              'choice to either die or become a vampire. Also, Alucard battles '
#              'a Vatican priest named Alexander Anderson after they are both '
#              'sent to kill the same vampire in Northern Ireland.',
#  'genres': ['Animation', 'Action', 'Fantasy'],
#  'imdb': {'id': 495212, 'rating': 8.5, 'votes': 8880},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-09-05 08:36:26.777000000',
#  'num_mflix_comments': 0,
#  'plot': 'The vampire Alucard and his newly sired ward Seras tries to protect '
#          'England from a war-crazed SS-Major who seeks to start an eternal war '
#          'with his vampire army.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTU5ZWExZjktMmI5MC00MjUwLTk0MjAtNDExMDk1ZDUzZWY3XkEyXkFqcGdeQXVyNjc3OTE4Nzk@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-MA',
#  'released': datetime.datetime(2006, 12, 5, 0, 0),
#  'runtime': 50,
#  'title': 'Hellsing Ultimate',
#  'type': 'series',
#  'writers': ['Kohta Hirano'],
#  'year': '2006è2012'}
# {'_id': ObjectId('573a13b6f29313caabd48af3'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Katie Gray', 'Victoria Harwood', 'Crispin Freeman', 'Ralph Lister'],
#  'countries': ['Japan'],
#  'fullplot': 'In flashback, Integra is seen assuming leadership of the '
#              'Hellsing organization as she resolves a conflict with her uncle '
#              'with the help of the vampire Alucard. In present day, Alucard '
#              'goes on a mission to the town of Cheddar to silence a vampiric '
#              'priest who has been killing townspeople, and in the process must '
#              'also present the young police girl Seras Victoria with the '
#              'choice to either die or become a vampire. Also, Alucard battles '
#              'a Vatican priest named Alexander Anderson after they are both '
#              'sent to kill the same vampire in Northern Ireland.',
#  'genres': ['Animation', 'Action', 'Fantasy'],
#  'imdb': {'id': 495212, 'rating': 8.5, 'votes': 8525},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-08-17 00:55:25.017000000',
#  'num_mflix_comments': 0,
#  'plot': 'The vampire Alucard and his newly sired ward Seras tries to protect '
#          'England from a war-crazed SS-Major who seeks to start an eternal war '
#          'with his vampire army.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTU5ZWExZjktMmI5MC00MjUwLTk0MjAtNDExMDk1ZDUzZWY3XkEyXkFqcGdeQXVyNjc3OTE4Nzk@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-MA',
#  'released': datetime.datetime(2006, 12, 5, 0, 0),
#  'runtime': 50,
#  'title': 'Hellsing Ultimate',
#  'tomatoes': {'dvd': datetime.datetime(2003, 12, 9, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 21, 18, 39, 56),
#               'viewer': {'meter': 93, 'numReviews': 1510, 'rating': 3.2}},
#  'type': 'series',
#  'writers': ['Kohta Hirano'],
#  'year': '2006è2012'}
# {'_id': ObjectId('573a1399f29313caabced750'),
#  'awards': {'nominations': 25,
#             'text': 'Won 1 Primetime Emmy. Another 16 wins & 25 nominations.',
#             'wins': 17},
#  'cast': ['Jerry Doyle', 'Mira Furlan', 'Richard Biggs', 'Bill Mumy'],
#  'countries': ['USA'],
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 105946, 'rating': 8.2, 'votes': 21109},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 07:39:16.083000000',
#  'num_mflix_comments': 0,
#  'plot': 'A space station in neutral territory is the focus of a unique five '
#          'year saga.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2Q3ZWM0YzgtMGU0Mi00OWM0LWIwNzctNmQ4NTUyYTk0ZWY2XkEyXkFqcGdeQXVyMzYyMzU2OA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1994, 1, 26, 0, 0),
#  'runtime': 45,
#  'title': 'Babylon 5',
#  'tomatoes': {'dvd': datetime.datetime(2009, 9, 15, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 18, 31, 13),
#               'viewer': {'numReviews': 5, 'rating': 0.0}},
#  'type': 'series',
#  'writers': ['J. Michael Straczynski'],
#  'year': '1994è1998'}
# {'_id': ObjectId('573a13ecf29313caabdd21a3'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['David Sandberg', 'Jorma Taccone', 'Steven Chew', 'Leopold Nilsson'],
#  'countries': ['Sweden'],
#  'directors': ['David Sandberg'],
#  'fullplot': 'During an unfortunate series of events a friend of Kung Fury is '
#              'assassinated by the most dangerous kung fu master criminal of '
#              'all time; Adolf Hitler, a.k.a Kung Fèhrer. Kung Fury decides to '
#              'travel back in time, to Nazi Germany, in order to kill Hitler '
#              'and end the Nazi empire once and for all.',
#  'genres': ['Short', 'Action', 'Comedy'],
#  'imdb': {'id': 3472226, 'rating': 8.3, 'votes': 24575},
#  'languages': ['English', 'Swedish', 'German'],
#  'lastupdated': '2015-09-10 17:20:55.477000000',
#  'num_mflix_comments': 2,
#  'plot': 'In 1985, Kung Fury, the toughest martial artist cop in Miami, goes '
#          'back in time to kill the worst criminal of all time - kung fuhrer '
#          'Hitler.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjQwMjU2ODU5NF5BMl5BanBnXkFtZTgwNTU1NjM4NTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 5, 28, 0, 0),
#  'runtime': 31,
#  'title': 'Kung Fury',
#  'type': 'movie',
#  'writers': ['David Sandberg'],
#  'year': 2015}

# %%
nolan_movies = collection.find({"directors": "Christopher Nolan", "imdb.rating": {"$gt":
8}}).sort("imdb.rating", -1).limit(3)

for movie in nolan_movies:
  pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13b5f29313caabd42722'),
#  'awards': {'nominations': 106,
#             'text': 'Won 2 Oscars. Another 142 wins & 106 nominations.',
#             'wins': 144},
#  'cast': ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Batman raises the stakes in his war on crime. With the help of '
#              'Lieutenant Jim Gordon and District Attorney Harvey Dent, Batman '
#              'sets out to dismantle the remaining criminal organizations that '
#              'plague the city streets. The partnership proves to be effective, '
#              'but they soon find themselves prey to a reign of chaos unleashed '
#              'by a rising criminal mastermind known to the terrified citizens '
#              'of Gotham as The Joker.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 468569, 'rating': 9.0, 'votes': 1495351},
#  'languages': ['English', 'Mandarin'],
#  'lastupdated': '2015-09-10 17:05:27.667000000',
#  'metacritic': 82,
#  'num_mflix_comments': 136,
#  'plot': 'When the menace known as the Joker wreaks havoc and chaos on the '
#          'people of Gotham, the caped crusader must come to terms with one of '
#          'the greatest psychological tests of his ability to fight injustice.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2008, 7, 18, 0, 0),
#  'runtime': 152,
#  'title': 'The Dark Knight',
#  'tomatoes': {'boxOffice': '$533.3M',
#               'consensus': 'Dark, complex and unforgettable, The Dark Knight '
#                            'succeeds not just as an entertaining comic book '
#                            'film, but as a richly thrilling crime saga.',
#               'critic': {'meter': 94, 'numReviews': 314, 'rating': 8.6},
#               'dvd': datetime.datetime(2008, 12, 9, 0, 0),
#               'fresh': 295,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 5, 30),
#               'production': 'Warner Bros. Pictures/Legendary',
#               'rotten': 19,
#               'viewer': {'meter': 94, 'numReviews': 1818515, 'rating': 4.4},
#               'website': 'http://thedarkknight.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Nolan (screenplay)',
#              'Christopher Nolan (screenplay)',
#              'Christopher Nolan (story)',
#              'David S. Goyer (story)',
#              'Bob Kane (characters)'],
#  'year': 2008}
# {'_id': ObjectId('573a13c5f29313caabd6ee61'),
#  'awards': {'nominations': 172,
#             'text': 'Won 4 Oscars. Another 158 wins & 172 nominations.',
#             'wins': 162},
#  'cast': ['Leonardo DiCaprio',
#           'Joseph Gordon-Levitt',
#           'Ellen Page',
#           'Tom Hardy'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Dom Cobb is a skilled thief, the absolute best in the dangerous '
#              'art of extraction, stealing valuable secrets from deep within '
#              'the subconscious during the dream state, when the mind is at its '
#              "most vulnerable. Cobb's rare ability has made him a coveted "
#              'player in this treacherous new world of corporate espionage, but '
#              'it has also made him an international fugitive and cost him '
#              'everything he has ever loved. Now Cobb is being offered a chance '
#              'at redemption. One last job could give him his life back but '
#              'only if he can accomplish the impossible-inception. Instead of '
#              'the perfect heist, Cobb and his team of specialists have to pull '
#              'off the reverse: their task is not to steal an idea but to plant '
#              'one. If they succeed, it could be the perfect crime. But no '
#              'amount of careful planning or expertise can prepare the team for '
#              'the dangerous enemy that seems to predict their every move. An '
#              'enemy that only Cobb could have seen coming.',
#  'genres': ['Action', 'Mystery', 'Sci-Fi'],
#  'imdb': {'id': 1375666, 'rating': 8.8, 'votes': 1294646},
#  'languages': ['English', 'Japanese', 'French'],
#  'lastupdated': '2015-09-12 00:29:01.430000000',
#  'metacritic': 74,
#  'num_mflix_comments': 1,
#  'plot': 'A thief who steals corporate secrets through use of dream-sharing '
#          'technology is given the inverse task of planting an idea into the '
#          'mind of a CEO.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2010, 7, 16, 0, 0),
#  'runtime': 148,
#  'title': 'Inception',
#  'tomatoes': {'boxOffice': '$292.6M',
#               'consensus': 'Smart, innovative, and thrilling, Inception is '
#                            'that rare summer blockbuster that succeeds '
#                            'viscerally as well as intellectually.',
#               'critic': {'meter': 86, 'numReviews': 326, 'rating': 8.1},
#               'dvd': datetime.datetime(2010, 12, 7, 0, 0),
#               'fresh': 281,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 13, 32),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 45,
#               'viewer': {'meter': 91, 'numReviews': 561365, 'rating': 4.2},
#               'website': 'http://inceptionmovie.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Christopher Nolan'],
#  'year': 2010}
# {'_id': ObjectId('573a13b9f29313caabd4ddff'),
#  'awards': {'nominations': 100,
#             'text': 'Won 1 Oscar. Another 44 wins & 100 nominations.',
#             'wins': 45},
#  'cast': ['Ellen Burstyn',
#           'Matthew McConaughey',
#           'Mackenzie Foy',
#           'John Lithgow'],
#  'countries': ['USA', 'UK', 'Canada'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'In the near future, Earth has been devastated by drought and '
#              'famine, causing a scarcity in food and extreme changes in '
#              'climate. When humanity is facing extinction, a mysterious rip in '
#              'the space-time continuum is discovered, giving mankind the '
#              'opportunity to widen its lifespan. A group of explorers must '
#              'travel beyond our solar system in search of a planet that can '
#              'sustain life. The crew of the Endurance are required to think '
#              'bigger and go further than any human in history as they embark '
#              'on an interstellar voyage into the unknown. Coop, the pilot of '
#              'the Endurance, must decide between seeing his children again and '
#              'the future of the human race.',
#  'genres': ['Adventure', 'Drama', 'Sci-Fi'],
#  'imdb': {'id': 816692, 'rating': 8.7, 'votes': 699518},
#  'languages': ['English'],
#  'lastupdated': '2015-08-18 00:04:49.173000000',
#  'metacritic': 74,
#  'num_mflix_comments': 1,
#  'plot': 'A team of explorers travel through a wormhole in space in an attempt '
#          "to ensure humanity's survival.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 11, 7, 0, 0),
#  'runtime': 169,
#  'title': 'Interstellar',
#  'tomatoes': {'consensus': 'Interstellar represents more of the thrilling, '
#                            'thought-provoking, and visually resplendent '
#                            'filmmaking moviegoers have come to expect from '
#                            'writer-director Christopher Nolan, even if its '
#                            'intellectual reach somewhat exceeds its grasp.',
#               'critic': {'meter': 72, 'numReviews': 293, 'rating': 7.0},
#               'dvd': datetime.datetime(2015, 3, 31, 0, 0),
#               'fresh': 210,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 8, 37),
#               'production': 'Paramount Pictures',
#               'rotten': 83,
#               'viewer': {'meter': 85, 'numReviews': 163082, 'rating': 4.1},
#               'website': 'http://www.InterstellarMovie.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Nolan', 'Christopher Nolan'],
#  'year': 2014}
